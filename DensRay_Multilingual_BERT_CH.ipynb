# %%
# !pip install transformers==2.8.0
# Out:
# Collecting transformers==2.8.0
#   Downloading https://files.pythonhosted.org/packages/a3/78/92cedda05552398352ed9784908b834ee32a0bd071a9b32de287327370b7/transformers-2.8.0-py3-none-any.whl (563kB)
#      |████████████████████████████████| 573kB 3.5MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/3b/88/49e772d686088e1278766ad68a463513642a2a877487decbd691dec02955/sentencepiece-0.1.90-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 16.1MB/s
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d1/3f/73c881ea4723e43c1e9acf317cf407fab3a278daab3a69c98dcac511c04f/tokenizers-0.5.2-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 19.3MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 43.0MB/s
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (1.13.10)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (0.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==2.8.0) (1.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.8.0) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.8.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.8.0) (0.15.0)
# Requirement already satisfied: botocore<1.17.0,>=1.16.10 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.8.0) (1.16.10)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.8.0) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.8.0) (0.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.8.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.8.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.8.0) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.8.0) (2.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.10->boto3->transformers==2.8.0) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.10->boto3->transformers==2.8.0) (0.15.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=431672583c64cd1e21d8c037e81864cd0d9e6e99407822b4358fb98baa4307cd
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sentencepiece, tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.90 tokenizers-0.5.2 transformers-2.8.0

# %%
# !wget https://raw.githubusercontent.com/huggingface/transformers/v2.8.0/examples/run_language_modeling.py
# Out:
# --2020-05-20 09:48:00--  https://raw.githubusercontent.com/huggingface/transformers/v2.8.0/examples/run_language_modeling.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34328 (34K) [text/plain]
# Saving to: ‘run_language_modeling.py’
#
# run_language_modeli 100%[===================>]  33.52K  --.-KB/s    in 0.01s
#
# 2020-05-20 09:48:00 (3.06 MB/s) - ‘run_language_modeling.py’ saved [34328/34328]

# %%
# !wget https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-2-v1.zip
# !unzip wikitext-2-v1.zip
# Out:
# --2020-05-20 09:48:02--  https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-2-v1.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.47.62
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.47.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4475746 (4.3M) [application/zip]
# Saving to: ‘wikitext-2-v1.zip’
#
# wikitext-2-v1.zip   100%[===================>]   4.27M  18.3MB/s    in 0.2s
#
# 2020-05-20 09:48:02 (18.3 MB/s) - ‘wikitext-2-v1.zip’ saved [4475746/4475746]
#
# Archive:  wikitext-2-v1.zip
#    creating: wikitext-2/
#   inflating: wikitext-2/wiki.test.tokens
#   inflating: wikitext-2/wiki.valid.tokens
#   inflating: wikitext-2/wiki.train.tokens

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Config

# %%
import torch
import transformers
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

config = 'base'
nlayer = 12 if config == 'base' else 24
nsamples = 5000

model = transformers.BertForMaskedLM.from_pretrained('bert-base-multilingual-uncased', output_hidden_states=True).to(device)
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-multilingual-uncased')
# turn on eval mode
model.eval()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=625.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=672271273.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=871891.0, style=ProgressStyle(descripti…
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(105879, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=105879, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Analogies

# %%
from torch.utils.data import DataLoader, Dataset
import tqdm

class GoogleAnalogies:
    def __init__(self, path='/content/drive/My Drive/questions-words.txt'):
        self.Lset = set()
        self.Rset = set()
        # this time only want the words in vocab !!!!!!!!!!
        with open(path,'r',encoding='utf8') as f:
            for line in f.readlines():
                line = line.strip().split(' ')
                self.Rset.update([line[1],line[3]])
                for w in [line[0],line[2]]:
                    if w in tokenizer.vocab.keys():
                        self.Lset.add(w)
                for w in [line[1],line[3]]:
                    if w in tokenizer.vocab.keys():
                        self.Rset.add(w)
        self.Lset = tokenizer.convert_tokens_to_ids(list(self.Lset))
        self.Rset = tokenizer.convert_tokens_to_ids(list(self.Rset))
        self.pieces = self.Lset+self.Rset
    """
    def get_embeddings_from_cropus(self, corpus, layer=11):
        L = torch.Tensor().to(device)
        R = torch.Tensor().to(device)
        for i in tqdm.trange(nsamples):
            # get useful idxs
            sentence = corpus.__getitem__(i)[0].cpu().tolist()
            vecs = model.bert(corpus.__getitem__(i))[2][layer+1][0][1:-1]#!!!!!!!!!!!
            for j in range(vecs.shape[0]):
                if corpus.labels[i][j]==1:
                    L = torch.cat((L, vecs[j].unsqueeze(0)))
                elif corpus.labels[i][j]==-1:
                    R = torch.cat((R, vecs[j].unsqueeze(0)))
        return L, R
    """               
    def get_embeddings_from_cropus(self, corpus, layer=11):
        #balanced
        L = torch.Tensor().to(device)
        R = torch.Tensor().to(device)
        #for i in tqdm.trange(nsamples):
        for i in tqdm.trange(nsamples):
            # get useful idxs
            sentence = corpus.__getitem__(i)[0].cpu().tolist()
            vecs = model.bert(corpus.__getitem__(i))[2][layer+1][0][1:-1]#!!!!!!!!!!!
            if L.shape[0]<nsamples//2:
                for j in range(vecs.shape[0]):
                    if corpus.labels[i][j]==1:
                        L = torch.cat((L, vecs[j].unsqueeze(0)))
                    elif corpus.labels[i][j]==-1:
                        R = torch.cat((R, vecs[j].unsqueeze(0)))
            else:
                for j in range(vecs.shape[0]):
                    if corpus.labels[i][j]==-1:
                        R = torch.cat((R, vecs[j].unsqueeze(0)))
            if L.shape[0]+R.shape[0]>=nsamples:
                break
        return L, R

# %%
analogy = GoogleAnalogies('/content/drive/My Drive/questions-words.txt')

# %% [markdown]
# # Dataset

# %%
from torch.utils.data import DataLoader, Dataset
import tqdm
import pickle

class TextDataset(Dataset):
    def __init__(self, path="/content/drive/My Drive/wikien_senttok_500k.txt"):
        self.examples, self.labels = pickle.load(open(path, 'rb'))
    
    def __len__(self):
        return len(self.examples)
    
    def __getitem__(self, i):
        return tokenizer.prepare_for_model(self.examples[i][:510], return_token_type_ids=False, return_tensors='pt')['input_ids'].to(device)
        #return torch.tensor(self.examples[i], dtype=torch.long).unsqueeze(0).to(device)

# %%
wiki = TextDataset("/content/drive/My Drive/wikien_senttok_500k.txt")

# %% [markdown]
# # DensRay

# %%
import tqdm

class DensRay:
    def __init__(self, Lemb, Remb):
        self.lemb = Lemb
        self.remb = Remb

    def fit(self, weights=None, normalize_D=True):
        """Fit DensRay
        Args:
            weights: only for binary model; how to weight the two
                summands; if none
                
                
                : apply dynamic weighting. Example input: [1.0, 1.0]
            normalize_D: bool whether to normalize the difference vectors with l2 norm
        """
        #self.computeA_binary_part1(normalize_D=normalize_D)
        self.A_equal = self.opsum(self.lemb) + self.opsum(self.remb)
        self.A_unequal = self.opsum(self.lemb, self.remb) + self.opsum(self.remb, self.lemb)
        self.computeA_binary_part2(weights=weights)
        self.compute_trafo()
        self.compute_mean_var()

    @staticmethod
    def opsum(a, b=None):
        if b is None: b = a
        out = -torch.ger(a.sum(dim=0), b.sum(dim=0))
        out = out + out.T
        out += b.shape[0] * torch.mm(a.T,a)
        out += a.shape[0] * torch.mm(b.T,b)
        return out

    @staticmethod
    def outer_product_sub_binary(v, M, normD):
        """Helper function to compute the sum of outer products

        While it is not very readable, it is more efficient than
        a brute force implementation.
        """
        d = v.unsqueeze(0) - M
        if normD:
            norm = d.norm(dim=1)
            norm[norm == 0] = 1
            d = d / (norm.unsqueeze(0).T)
        return torch.mm(d.T, d)
    
    def computeA_binary_part1(self, normalize_D=False):
        """First part of computing the matrix A.
        Args:
            normalize_D: bool whether to normalize the difference vectors with l2 norm.
        """
        dim = self.lemb.shape[1]
        self.A_equal = torch.zeros((dim, dim)).to(device)
        self.A_unequal = torch.zeros((dim, dim)).to(device)
        for ipos in tqdm.trange(self.lemb.shape[0]):
            v = self.lemb[ipos]
            self.A_equal += self.outer_product_sub_binary(v, self.lemb, normalize_D)
            self.A_unequal += self.outer_product_sub_binary(v, self.remb, normalize_D)
        for ineg in tqdm.trange(self.remb.shape[0]):
            v = self.remb[ineg]
            self.A_equal += self.outer_product_sub_binary(v, self.remb, normalize_D)
            self.A_unequal += self.outer_product_sub_binary(v, self.lemb, normalize_D)

    def computeA_binary_part2(self, weights=None):
        """Second part of computing the matrix A.
        Args:
            weights: only for binary model; how to weight the two 
                summands; if none: apply dynamic weighting. Example input: [1.0, 1.0]
        """
        if weights is None:
            weights = [1 / (2 * self.lemb.shape[0] * self.remb.shape[0]), 1 /
                       (self.lemb.shape[0]**2 + self.remb.shape[0]**2)]
        # normalize matrices for numerical reasons
        # note that this does not change the eigenvectors
        n1 = self.A_unequal.max()
        n2 = self.A_equal.max()
        weights = [weights[0] / max(n1, n2), weights[1] / max(n1, n2)]
        self.A = weights[0] * self.A_unequal - weights[1] * self.A_equal

    def compute_trafo(self):
        """Given A, this function computes the actual Transformation.
        It essentially just does an eigenvector decomposition.
        """
        eigvals, eigvecs = self.A.symeig(eigenvectors=True)
        # need to sort the eigenvalues
        idx = eigvals.argsort(descending=True)
        eigvals, self.eigvecs = eigvals[idx], eigvecs[:, idx]
    
    def compute_mean_var(self):
        first_dim = torch.mm(torch.cat((self.lemb, self.remb)), self.eigvecs)[:, 0]
        self.mean = first_dim.mean()
        self.std = first_dim.var().sqrt()

# %% [markdown]
# # Templates

# %%
import re

class Template:
    def __init__(self, path='/content/drive/My Drive/professions.json'):
        with open(path,'r',encoding='utf8') as f:
            titles = re.sub('[^a-z_]',' ',f.read()).split()
        self.lines = [re.sub('_',' ',tokenizer.mask_token+' is a '+i+' .') for i in titles]
        self.examples = tokenizer.batch_encode_plus(self.lines, add_special_tokens=True, max_length=128)["input_ids"]
        self.getbaseline()
    
    def getbaseline(self):
        self.baseline = []
        for i in self.examples:
            i = torch.tensor(i, dtype=torch.long).unsqueeze(0).to(device)
            output = model(i)
            mask_hidden_state = output[0].squeeze(0)[1]
            softmax = torch.nn.Softmax(dim=0)
            torch.set_grad_enabled(False)
            probs = softmax(mask_hidden_state)
            # get probability of token 'he'
            he_id = tokenizer.convert_tokens_to_ids('he')
            #print('he probability', probs[he_id].item())
            # get probability of token 'she'
            she_id = tokenizer.convert_tokens_to_ids('she')
            #print('she probability', probs[she_id].item())
            self.baseline.append([probs[he_id].item(), probs[she_id].item()])
        
template = Template('/content/drive/My Drive/professions.json')

# %% [markdown]
# # Train

# %%
def train_only(corpus=None, layer=11):
    # prepare training data for densray
    print('start')
    L, R = analogy.get_embeddings_from_cropus(corpus, layer)
    # compute densray
    densray = DensRay(L,R)
    densray.fit()
    torch.save(densray.eigvecs, '/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(layer)+'.pt')
    torch.save(densray.mean, '/content/drive/My Drive/mean_multilingual_'+str(nsamples)+'_'+str(layer)+'.pt')
    torch.save(densray.std, '/content/drive/My Drive/std_multilingual_'+str(nsamples)+'_'+str(layer)+'.pt')
    print(str(layer)+' saved')

# %%
for l in range(nlayer):
    print("Layer ", l)
    train_only(wiki, layer=l)

# %% [markdown]
# # Eval

# %%
def get_eigvecs_dict(layer=-1):
    eigvecs_dict = {}
    #-1:apply to all layers
    if layer == -1:
        for l in range(nlayer):
            eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', True)
    elif layer ==-2:
        for l in range(nlayer):
            eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', False)
    else:
        for l in range(nlayer):
            if l==layer:
                eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', True)
            else:
                eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', False)
    return eigvecs_dict

# %%
import densray_bert

def eval(temp=Template(), he='he', she='she'):
    predictions = []
    for l in range(-1,0):
        # get model
        model = densray_bert.BertForMaskedLM_1.from_pretrained('bert-base-multilingual-uncased', eigvecs_dict=get_eigvecs_dict(l)).to(device)
        model.eval() 
        # eval
        prediction = []
        for i in tqdm.trange(len(temp.examples)):
            vec = torch.tensor(temp.examples[i], dtype=torch.long).unsqueeze(0).to(device)
            output = model(vec)
            mask_hidden_state = output[0].squeeze(0)[1]
            softmax = torch.nn.Softmax(dim=0)
            torch.set_grad_enabled(False)
            probs = softmax(mask_hidden_state)
            he_id = tokenizer.convert_tokens_to_ids(he)
            she_id = tokenizer.convert_tokens_to_ids(she)
            prediction.append([probs[he_id].item(), probs[she_id].item()])
        predictions.append(prediction)
    return predictions

# %%
predictions = eval(template)
# Out:
# 100%|██████████| 320/320 [00:06<00:00, 50.63it/s]
# 100%|██████████| 320/320 [00:05<00:00, 59.26it/s]
# 100%|██████████| 320/320 [00:05<00:00, 59.67it/s]
# 100%|██████████| 320/320 [00:05<00:00, 55.67it/s]
# 100%|██████████| 320/320 [00:05<00:00, 58.67it/s]
# 100%|██████████| 320/320 [00:05<00:00, 60.17it/s]
# 100%|██████████| 320/320 [00:05<00:00, 55.94it/s]
# 100%|██████████| 320/320 [00:05<00:00, 58.27it/s]
# 100%|██████████| 320/320 [00:05<00:00, 55.89it/s]
# 100%|██████████| 320/320 [00:05<00:00, 60.77it/s]
# 100%|██████████| 320/320 [00:05<00:00, 58.51it/s]
# 100%|██████████| 320/320 [00:05<00:00, 58.08it/s]
# 100%|██████████| 320/320 [00:05<00:00, 58.48it/s]

# %%
print('mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))')
baseline = torch.Tensor(template_ch.baseline)
print(torch.mean(baseline,dim=0), torch.var(baseline,dim=0), (baseline[:,0]-baseline[:,1]).mean(), (baseline[:,0]-baseline[:,1]).var(), '\n')

for i in torch.Tensor(predictions_ch):
    print(torch.mean(i,dim=0), torch.var(i,dim=0), (i[:,0]-i[:,1]).mean(), (i[:,0]-i[:,1]).var())
# Out:
# mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-11dc7373390a> in <module>()
#       1 print('mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))')
# ----> 2 baseline = torch.Tensor(template_ch.baseline)
#       3 print(torch.mean(baseline,dim=0), torch.var(baseline,dim=0), (baseline[:,0]-baseline[:,1]).mean(), (baseline[:,0]-baseline[:,1]).var(), '\n')
#       4
#       5 for i in torch.Tensor(predictions_ch):
#
# NameError: name 'template_ch' is not defined

# %%
print('mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))')
baseline = torch.Tensor(template_ch.baseline)
print([round(i,4) for i in torch.mean(baseline,dim=0).tolist()], [round(i,4) for i in torch.var(baseline,dim=0).tolist()], 
      round(float((baseline[:,0]-baseline[:,1]).mean()),4), round(float((baseline[:,0]-baseline[:,1]).var()),4), '\n')

for i in torch.Tensor(predictions_ch):
    print([round(i,4) for i in torch.mean(i,dim=0).tolist()], [round(i,4) for i in torch.var(i,dim=0).tolist()], 
          round(float((i[:,0]-i[:,1]).mean()),4), round(float((i[:,0]-i[:,1]).var()),4))

# %%
for i in range(len(template.lines)):
    print("sentence: ", template.lines[i])
    print("prediction: ", predictions[0][i])
    print("baseline: ", template.baseline[i], "\n")
# Out:
# sentence:  [MASK] is a accountant .
# prediction:  [0.39493316411972046, 0.1398414820432663]
# baseline:  [0.5873933434486389, 0.12361506372690201]
#
# sentence:  [MASK] is a acquaintance .
# prediction:  [0.1462639570236206, 0.07365661859512329]
# baseline:  [0.2706422209739685, 0.14534759521484375]
#
# sentence:  [MASK] is a actor .
# prediction:  [0.4284520149230957, 0.017177168279886246]
# baseline:  [0.6564431190490723, 0.019211383536458015]
#
# sentence:  [MASK] is a actress .
# prediction:  [0.041298236697912216, 0.5127901434898376]
# baseline:  [0.03602493181824684, 0.7255024313926697]
#
# sentence:  [MASK] is a adjunct professor .
# prediction:  [0.5073726773262024, 0.17620475590229034]
# baseline:  [0.6823557615280151, 0.16118383407592773]
#
# sentence:  [MASK] is a administrator .
# prediction:  [0.34964877367019653, 0.13183927536010742]
# baseline:  [0.5344631671905518, 0.16709540784358978]
#
# sentence:  [MASK] is a adventurer .
# prediction:  [0.25711262226104736, 0.06979017704725266]
# baseline:  [0.4459293484687805, 0.07081533223390579]
#
# sentence:  [MASK] is a advocate .
# prediction:  [0.37256714701652527, 0.24615228176116943]
# baseline:  [0.504311203956604, 0.29387587308883667]
#
# sentence:  [MASK] is a aide .
# prediction:  [0.1850527673959732, 0.08449449390172958]
# baseline:  [0.3440078794956207, 0.13680699467658997]
#
# sentence:  [MASK] is a alderman .
# prediction:  [0.5787007212638855, 0.03447115421295166]
# baseline:  [0.7436898350715637, 0.029557783156633377]
#
# sentence:  [MASK] is a alter ego .
# prediction:  [0.08252909779548645, 0.0366598404943943]
# baseline:  [0.16447193920612335, 0.06388027966022491]
#
# sentence:  [MASK] is a ambassador .
# prediction:  [0.42341968417167664, 0.15945006906986237]
# baseline:  [0.6191748976707458, 0.17755551636219025]
#
# sentence:  [MASK] is a analyst .
# prediction:  [0.42040807008743286, 0.10760325938463211]
# baseline:  [0.6207019686698914, 0.10426368564367294]
#
# sentence:  [MASK] is a anthropologist .
# prediction:  [0.24946925044059753, 0.12783536314964294]
# baseline:  [0.38567915558815, 0.1429813802242279]
#
# sentence:  [MASK] is a archaeologist .
# prediction:  [0.3088754117488861, 0.14105261862277985]
# baseline:  [0.4715522527694702, 0.14532333612442017]
#
# sentence:  [MASK] is a archbishop .
# prediction:  [0.5754939913749695, 0.018301619216799736]
# baseline:  [0.8183688521385193, 0.0165699515491724]
#
# sentence:  [MASK] is a architect .
# prediction:  [0.393892377614975, 0.12109648436307907]
# baseline:  [0.5957005620002747, 0.11679305881261826]
#
# sentence:  [MASK] is a artist .
# prediction:  [0.28685420751571655, 0.2084251493215561]
# baseline:  [0.4317246675491333, 0.2672902047634125]
#
# sentence:  [MASK] is a artiste .
# prediction:  [0.285091757774353, 0.2646578252315521]
# baseline:  [0.4025840163230896, 0.36441367864608765]
#
# sentence:  [MASK] is a assassin .
# prediction:  [0.2385246902704239, 0.11339341104030609]
# baseline:  [0.4353979527950287, 0.14075347781181335]
#
# sentence:  [MASK] is a assistant professor .
# prediction:  [0.420453816652298, 0.1778794676065445]
# baseline:  [0.5981308817863464, 0.18247945606708527]
#
# sentence:  [MASK] is a associate dean .
# prediction:  [0.4293575882911682, 0.06348026543855667]
# baseline:  [0.6161766052246094, 0.07159101217985153]
#
# sentence:  [MASK] is a associate professor .
# prediction:  [0.4560292661190033, 0.13944390416145325]
# baseline:  [0.6339237093925476, 0.1407591998577118]
#
# sentence:  [MASK] is a astronaut .
# prediction:  [0.27823400497436523, 0.20942142605781555]
# baseline:  [0.41091978549957275, 0.29223233461380005]
#
# sentence:  [MASK] is a astronomer .
# prediction:  [0.332546591758728, 0.102322056889534]
# baseline:  [0.5058329105377197, 0.10796026885509491]
#
# sentence:  [MASK] is a athlete .
# prediction:  [0.3090749979019165, 0.2406548410654068]
# baseline:  [0.43710941076278687, 0.2924720346927643]
#
# sentence:  [MASK] is a athletic director .
# prediction:  [0.6169417500495911, 0.044982604682445526]
# baseline:  [0.8136743903160095, 0.03424537554383278]
#
# sentence:  [MASK] is a attorney .
# prediction:  [0.4060284495353699, 0.15066900849342346]
# baseline:  [0.5851834416389465, 0.15675805509090424]
#
# sentence:  [MASK] is a author .
# prediction:  [0.32909104228019714, 0.35743725299835205]
# baseline:  [0.414479523897171, 0.4181381165981293]
#
# sentence:  [MASK] is a baker .
# prediction:  [0.33117538690567017, 0.08078974485397339]
# baseline:  [0.5674713253974915, 0.08937760442495346]
#
# sentence:  [MASK] is a ballerina .
# prediction:  [0.018198993057012558, 0.5566812753677368]
# baseline:  [0.014076193794608116, 0.7875159978866577]
#
# sentence:  [MASK] is a ballplayer .
# prediction:  [0.197078138589859, 0.02820114605128765]
# baseline:  [0.3199966549873352, 0.031986162066459656]
#
# sentence:  [MASK] is a banker .
# prediction:  [0.3882110118865967, 0.11406397074460983]
# baseline:  [0.5879191756248474, 0.11516140401363373]
#
# sentence:  [MASK] is a barber .
# prediction:  [0.2957790195941925, 0.1783798485994339]
# baseline:  [0.4838133752346039, 0.2142227441072464]
#
# sentence:  [MASK] is a baron .
# prediction:  [0.5115669369697571, 0.030209707096219063]
# baseline:  [0.7382093667984009, 0.032022036612033844]
#
# sentence:  [MASK] is a barrister .
# prediction:  [0.39091721177101135, 0.11288508027791977]
# baseline:  [0.5770413875579834, 0.09719149023294449]
#
# sentence:  [MASK] is a bartender .
# prediction:  [0.07076563686132431, 0.011179101653397083]
# baseline:  [0.1600128561258316, 0.015789734199643135]
#
# sentence:  [MASK] is a biologist .
# prediction:  [0.3793031573295593, 0.14077259600162506]
# baseline:  [0.549598753452301, 0.15115581452846527]
#
# sentence:  [MASK] is a bishop .
# prediction:  [0.603247880935669, 0.04663794860243797]
# baseline:  [0.8073640465736389, 0.042887717485427856]
#
# sentence:  [MASK] is a bodyguard .
# prediction:  [0.24935364723205566, 0.12869001924991608]
# baseline:  [0.4329249858856201, 0.1723799854516983]
#
# sentence:  [MASK] is a bookkeeper .
# prediction:  [0.28899136185646057, 0.21107420325279236]
# baseline:  [0.4477536976337433, 0.24862799048423767]
#
# sentence:  [MASK] is a boss .
# prediction:  [0.25985896587371826, 0.06051095947623253]
# baseline:  [0.4590705335140228, 0.06563779711723328]
#
# sentence:  [MASK] is a boxer .
# prediction:  [0.3502059578895569, 0.07039986550807953]
# baseline:  [0.5668385028839111, 0.06563903391361237]
#
# sentence:  [MASK] is a broadcaster .
# prediction:  [0.33739906549453735, 0.11275604367256165]
# baseline:  [0.5261701941490173, 0.11341320723295212]
#
# sentence:  [MASK] is a broker .
# prediction:  [0.34935715794563293, 0.11037182062864304]
# baseline:  [0.5360152721405029, 0.10216058790683746]
#
# sentence:  [MASK] is a bureaucrat .
# prediction:  [0.336174875497818, 0.03382360562682152]
# baseline:  [0.5858402252197266, 0.03733564540743828]
#
# sentence:  [MASK] is a businessman .
# prediction:  [0.5380977392196655, 0.020557401701807976]
# baseline:  [0.7421808242797852, 0.020937176421284676]
#
# sentence:  [MASK] is a businesswoman .
# prediction:  [0.04762714356184006, 0.5844196677207947]
# baseline:  [0.04073750600218773, 0.774867057800293]
#
# sentence:  [MASK] is a butcher .
# prediction:  [0.43916893005371094, 0.0426710806787014]
# baseline:  [0.6638538837432861, 0.03615907207131386]
#
# sentence:  [MASK] is a butler .
# prediction:  [0.31619223952293396, 0.13604485988616943]
# baseline:  [0.5180850028991699, 0.16435958445072174]
#
# sentence:  [MASK] is a cab driver .
# prediction:  [0.3703744113445282, 0.07546689361333847]
# baseline:  [0.5718113780021667, 0.07780732214450836]
#
# sentence:  [MASK] is a cabbie .
# prediction:  [0.03886687010526657, 0.04951564595103264]
# baseline:  [0.048817478120326996, 0.07534962892532349]
#
# sentence:  [MASK] is a cameraman .
# prediction:  [0.3681246042251587, 0.08913655579090118]
# baseline:  [0.5884992480278015, 0.08816748112440109]
#
# sentence:  [MASK] is a campaigner .
# prediction:  [0.3200075030326843, 0.2119358628988266]
# baseline:  [0.4697938561439514, 0.2433985471725464]
#
# sentence:  [MASK] is a captain .
# prediction:  [0.39402756094932556, 0.057221777737140656]
# baseline:  [0.6084946393966675, 0.06009894609451294]
#
# sentence:  [MASK] is a cardiologist .
# prediction:  [0.4250088930130005, 0.19881409406661987]
# baseline:  [0.5828389525413513, 0.1994185596704483]
#
# sentence:  [MASK] is a caretaker .
# prediction:  [0.22852876782417297, 0.14005886018276215]
# baseline:  [0.3947368860244751, 0.21088701486587524]
#
# sentence:  [MASK] is a carpenter .
# prediction:  [0.3485880494117737, 0.14140838384628296]
# baseline:  [0.5367571115493774, 0.156633198261261]
#
# sentence:  [MASK] is a cartoonist .
# prediction:  [0.3486728072166443, 0.14659982919692993]
# baseline:  [0.5361733436584473, 0.14294089376926422]
#
# sentence:  [MASK] is a cellist .
# prediction:  [0.3715600073337555, 0.16397647559642792]
# baseline:  [0.5498620271682739, 0.16352416574954987]
#
# sentence:  [MASK] is a chancellor .
# prediction:  [0.4989805817604065, 0.0693836659193039]
# baseline:  [0.704778254032135, 0.06715071946382523]
#
# sentence:  [MASK] is a chaplain .
# prediction:  [0.49715718626976013, 0.05950070545077324]
# baseline:  [0.7314099669456482, 0.05590775981545448]
#
# sentence:  [MASK] is a character .
# prediction:  [0.0729631707072258, 0.026374854147434235]
# baseline:  [0.12704041600227356, 0.03996569663286209]
#
# sentence:  [MASK] is a chef .
# prediction:  [0.31466326117515564, 0.04926636815071106]
# baseline:  [0.5446670651435852, 0.05565159395337105]
#
# sentence:  [MASK] is a chemist .
# prediction:  [0.41783061623573303, 0.12464026361703873]
# baseline:  [0.5918185114860535, 0.11990030109882355]
#
# sentence:  [MASK] is a choreographer .
# prediction:  [0.3756926655769348, 0.17851348221302032]
# baseline:  [0.5549176335334778, 0.19033898413181305]
#
# sentence:  [MASK] is a cinematographer .
# prediction:  [0.3672620356082916, 0.10829173028469086]
# baseline:  [0.5713212490081787, 0.10553775727748871]
#
# sentence:  [MASK] is a citizen .
# prediction:  [0.45093071460723877, 0.11114506423473358]
# baseline:  [0.6352244019508362, 0.11706256121397018]
#
# sentence:  [MASK] is a civil servant .
# prediction:  [0.46836039423942566, 0.1604856550693512]
# baseline:  [0.6470046043395996, 0.1420372575521469]
#
# sentence:  [MASK] is a cleric .
# prediction:  [0.44621598720550537, 0.045916687697172165]
# baseline:  [0.687531590461731, 0.045306168496608734]
#
# sentence:  [MASK] is a clerk .
# prediction:  [0.4044933021068573, 0.1353529393672943]
# baseline:  [0.5960581302642822, 0.16088558733463287]
#
# sentence:  [MASK] is a coach .
# prediction:  [0.5852158665657043, 0.06885916739702225]
# baseline:  [0.78459233045578, 0.06225062534213066]
#
# sentence:  [MASK] is a collector .
# prediction:  [0.4846055805683136, 0.1120038852095604]
# baseline:  [0.6893388628959656, 0.11565051972866058]
#
# sentence:  [MASK] is a colonel .
# prediction:  [0.46589329838752747, 0.0489315427839756]
# baseline:  [0.6935012340545654, 0.045014988631010056]
#
# sentence:  [MASK] is a columnist .
# prediction:  [0.3239056169986725, 0.19922330975532532]
# baseline:  [0.4836038053035736, 0.22056126594543457]
#
# sentence:  [MASK] is a comedian .
# prediction:  [0.34496116638183594, 0.1070476844906807]
# baseline:  [0.5416749119758606, 0.11212535202503204]
#
# sentence:  [MASK] is a comic .
# prediction:  [0.011633015237748623, 0.005689712241292]
# baseline:  [0.011515324003994465, 0.007190930191427469]
#
# sentence:  [MASK] is a commander .
# prediction:  [0.33104562759399414, 0.07324223965406418]
# baseline:  [0.5356645584106445, 0.08794805407524109]
#
# sentence:  [MASK] is a commentator .
# prediction:  [0.4940166473388672, 0.08140519261360168]
# baseline:  [0.6986275315284729, 0.07807891815900803]
#
# sentence:  [MASK] is a commissioner .
# prediction:  [0.44498178362846375, 0.042672786861658096]
# baseline:  [0.6942521929740906, 0.045147962868213654]
#
# sentence:  [MASK] is a composer .
# prediction:  [0.3726513683795929, 0.14206814765930176]
# baseline:  [0.5660552978515625, 0.1617334932088852]
#
# sentence:  [MASK] is a conductor .
# prediction:  [0.48545128107070923, 0.050941102206707]
# baseline:  [0.7072963118553162, 0.04809316620230675]
#
# sentence:  [MASK] is a confesses .
# prediction:  [0.32430848479270935, 0.10028477013111115]
# baseline:  [0.5222796201705933, 0.12277305871248245]
#
# sentence:  [MASK] is a congressman .
# prediction:  [0.5825509428977966, 0.052634838968515396]
# baseline:  [0.7618787288665771, 0.0480753555893898]
#
# sentence:  [MASK] is a constable .
# prediction:  [0.46824201941490173, 0.11196611076593399]
# baseline:  [0.6774219870567322, 0.1032927855849266]
#
# sentence:  [MASK] is a consultant .
# prediction:  [0.3957424461841583, 0.12011108547449112]
# baseline:  [0.5896010398864746, 0.13994891941547394]
#
# sentence:  [MASK] is a cop .
# prediction:  [0.29265129566192627, 0.09527081996202469]
# baseline:  [0.5146889090538025, 0.11890491098165512]
#
# sentence:  [MASK] is a correspondent .
# prediction:  [0.3187201917171478, 0.1871846616268158]
# baseline:  [0.48608189821243286, 0.26419776678085327]
#
# sentence:  [MASK] is a councilman .
# prediction:  [0.5305322408676147, 0.06985865533351898]
# baseline:  [0.7204031944274902, 0.06019093096256256]
#
# sentence:  [MASK] is a councilor .
# prediction:  [0.40063124895095825, 0.10092459619045258]
# baseline:  [0.6113662123680115, 0.09901855885982513]
#
# sentence:  [MASK] is a counselor .
# prediction:  [0.4168318212032318, 0.18519587814807892]
# baseline:  [0.5882969498634338, 0.19312475621700287]
#
# sentence:  [MASK] is a critic .
# prediction:  [0.4582449495792389, 0.14368566870689392]
# baseline:  [0.6439236402511597, 0.15308023989200592]
#
# sentence:  [MASK] is a crooner .
# prediction:  [0.3224843442440033, 0.07137062400579453]
# baseline:  [0.5166844129562378, 0.07896929979324341]
#
# sentence:  [MASK] is a crusader .
# prediction:  [0.2603744864463806, 0.05604858323931694]
# baseline:  [0.5090487003326416, 0.0668567568063736]
#
# sentence:  [MASK] is a curator .
# prediction:  [0.473478227853775, 0.15174070000648499]
# baseline:  [0.6654971241950989, 0.14886268973350525]
#
# sentence:  [MASK] is a custodian .
# prediction:  [0.4798519015312195, 0.0680788978934288]
# baseline:  [0.7193687558174133, 0.06540179997682571]
#
# sentence:  [MASK] is a dad .
# prediction:  [0.18510913848876953, 0.056258492171764374]
# baseline:  [0.3430309295654297, 0.09171071648597717]
#
# sentence:  [MASK] is a dancer .
# prediction:  [0.20866626501083374, 0.2283022701740265]
# baseline:  [0.3220878541469574, 0.33903923630714417]
#
# sentence:  [MASK] is a dean .
# prediction:  [0.42966559529304504, 0.033803097903728485]
# baseline:  [0.6637520790100098, 0.04049967601895332]
#
# sentence:  [MASK] is a dentist .
# prediction:  [0.4133010506629944, 0.15225578844547272]
# baseline:  [0.5808016061782837, 0.16111797094345093]
#
# sentence:  [MASK] is a deputy .
# prediction:  [0.3449245095252991, 0.12072901427745819]
# baseline:  [0.5442975163459778, 0.15432162582874298]
#
# sentence:  [MASK] is a dermatologist .
# prediction:  [0.3184371590614319, 0.13706722855567932]
# baseline:  [0.4820534884929657, 0.14074842631816864]
#
# sentence:  [MASK] is a detective .
# prediction:  [0.18529215455055237, 0.17150896787643433]
# baseline:  [0.3113681674003601, 0.25581589341163635]
#
# sentence:  [MASK] is a diplomat .
# prediction:  [0.4539676308631897, 0.14360463619232178]
# baseline:  [0.6474205255508423, 0.14512848854064941]
#
# sentence:  [MASK] is a director .
# prediction:  [0.3762802183628082, 0.07155066728591919]
# baseline:  [0.605804443359375, 0.08761924505233765]
#
# sentence:  [MASK] is a disc jockey .
# prediction:  [0.23683041334152222, 0.04286692291498184]
# baseline:  [0.4281432330608368, 0.04734458401799202]
#
# sentence:  [MASK] is a doctor .
# prediction:  [0.3940037190914154, 0.11375260353088379]
# baseline:  [0.6027851700782776, 0.1399899125099182]
#
# sentence:  [MASK] is a doctoral student .
# prediction:  [0.36321961879730225, 0.18194395303726196]
# baseline:  [0.5239500999450684, 0.2127193957567215]
#
# sentence:  [MASK] is a drug addict .
# prediction:  [0.0688975602388382, 0.004668682813644409]
# baseline:  [0.064588263630867, 0.009790722280740738]
#
# sentence:  [MASK] is a drummer .
# prediction:  [0.36093324422836304, 0.04908337816596031]
# baseline:  [0.5744338035583496, 0.047184742987155914]
#
# sentence:  [MASK] is a economics professor .
# prediction:  [0.4495358467102051, 0.1797705441713333]
# baseline:  [0.6511590480804443, 0.1487596035003662]
#
# sentence:  [MASK] is a economist .
# prediction:  [0.36536723375320435, 0.1275632083415985]
# baseline:  [0.5421938896179199, 0.13176454603672028]
#
# sentence:  [MASK] is a editor .
# prediction:  [0.41610124707221985, 0.1355709731578827]
# baseline:  [0.6032410264015198, 0.14781858026981354]
#
# sentence:  [MASK] is a educator .
# prediction:  [0.3001598119735718, 0.26714491844177246]
# baseline:  [0.40955036878585815, 0.3274650573730469]
#
# sentence:  [MASK] is a electrician .
# prediction:  [0.0506087988615036, 0.0028601731173694134]
# baseline:  [0.07283196598291397, 0.0035642022266983986]
#
# sentence:  [MASK] is a employee .
# prediction:  [0.2507862448692322, 0.11346050351858139]
# baseline:  [0.3970417380332947, 0.1669953316450119]
#
# sentence:  [MASK] is a entertainer .
# prediction:  [0.24115131795406342, 0.2655765414237976]
# baseline:  [0.3445429801940918, 0.3712187111377716]
#
# sentence:  [MASK] is a entrepreneur .
# prediction:  [0.3784293234348297, 0.1566011756658554]
# baseline:  [0.5643957257270813, 0.15520334243774414]
#
# sentence:  [MASK] is a environmentalist .
# prediction:  [0.31608304381370544, 0.19381526112556458]
# baseline:  [0.45723819732666016, 0.21550031006336212]
#
# sentence:  [MASK] is a envoy .
# prediction:  [0.14269714057445526, 0.02706938423216343]
# baseline:  [0.37898215651512146, 0.04725002497434616]
#
# sentence:  [MASK] is a epidemiologist .
# prediction:  [0.4435555040836334, 0.16325418651103973]
# baseline:  [0.6162839531898499, 0.15798059105873108]
#
# sentence:  [MASK] is a evangelist .
# prediction:  [0.4577561616897583, 0.01685868389904499]
# baseline:  [0.7284915447235107, 0.018608607351779938]
#
# sentence:  [MASK] is a farmer .
# prediction:  [0.43699783086776733, 0.08868087828159332]
# baseline:  [0.6446231603622437, 0.09029611200094223]
#
# sentence:  [MASK] is a fashion designer .
# prediction:  [0.10941555351018906, 0.20532427728176117]
# baseline:  [0.1795869767665863, 0.3212908208370209]
#
# sentence:  [MASK] is a fighter pilot .
# prediction:  [0.3375367820262909, 0.10761380940675735]
# baseline:  [0.537886381149292, 0.11840318888425827]
#
# sentence:  [MASK] is a filmmaker .
# prediction:  [0.335940420627594, 0.1426040232181549]
# baseline:  [0.5163712501525879, 0.1423071175813675]
#
# sentence:  [MASK] is a financier .
# prediction:  [0.38111838698387146, 0.07494131475687027]
# baseline:  [0.5924037098884583, 0.0679224282503128]
#
# sentence:  [MASK] is a firebrand .
# prediction:  [0.006335945334285498, 0.004546644166111946]
# baseline:  [0.008694654330611229, 0.005726412404328585]
#
# sentence:  [MASK] is a firefighter .
# prediction:  [0.2717472016811371, 0.16102653741836548]
# baseline:  [0.4550858736038208, 0.17799389362335205]
#
# sentence:  [MASK] is a fireman .
# prediction:  [0.41016045212745667, 0.05623966455459595]
# baseline:  [0.6259940266609192, 0.05263056606054306]
#
# sentence:  [MASK] is a fisherman .
# prediction:  [0.4147662818431854, 0.09513486176729202]
# baseline:  [0.6216483116149902, 0.09877923130989075]
#
# sentence:  [MASK] is a footballer .
# prediction:  [0.45098093152046204, 0.020011039450764656]
# baseline:  [0.6719995737075806, 0.01750457100570202]
#
# sentence:  [MASK] is a foreman .
# prediction:  [0.38469240069389343, 0.07581771165132523]
# baseline:  [0.595914900302887, 0.07739771902561188]
#
# sentence:  [MASK] is a freelance writer .
# prediction:  [0.25527554750442505, 0.24352896213531494]
# baseline:  [0.3510836064815521, 0.2699141800403595]
#
# sentence:  [MASK] is a gangster .
# prediction:  [0.2666335999965668, 0.06413350254297256]
# baseline:  [0.45579731464385986, 0.06920412182807922]
#
# sentence:  [MASK] is a gardener .
# prediction:  [0.32215678691864014, 0.1348087191581726]
# baseline:  [0.5119125247001648, 0.13977918028831482]
#
# sentence:  [MASK] is a geologist .
# prediction:  [0.40348103642463684, 0.13827845454216003]
# baseline:  [0.5878620743751526, 0.13665249943733215]
#
# sentence:  [MASK] is a goalkeeper .
# prediction:  [0.5842655897140503, 0.020100194960832596]
# baseline:  [0.7955344319343567, 0.01601547934114933]
#
# sentence:  [MASK] is a graphic designer .
# prediction:  [0.2019234150648117, 0.09630237519741058]
# baseline:  [0.36260950565338135, 0.12662163376808167]
#
# sentence:  [MASK] is a guidance counselor .
# prediction:  [0.3034723699092865, 0.31202417612075806]
# baseline:  [0.4497087895870209, 0.30492231249809265]
#
# sentence:  [MASK] is a guitarist .
# prediction:  [0.33882415294647217, 0.0558353066444397]
# baseline:  [0.5445254445075989, 0.05509049445390701]
#
# sentence:  [MASK] is a hairdresser .
# prediction:  [0.168787881731987, 0.25806018710136414]
# baseline:  [0.26189446449279785, 0.3493240177631378]
#
# sentence:  [MASK] is a handyman .
# prediction:  [0.3605199456214905, 0.11406958848237991]
# baseline:  [0.5820329189300537, 0.1199602410197258]
#
# sentence:  [MASK] is a headmaster .
# prediction:  [0.28722599148750305, 0.10085349529981613]
# baseline:  [0.45535874366760254, 0.11300139874219894]
#
# sentence:  [MASK] is a historian .
# prediction:  [0.435758501291275, 0.11277955770492554]
# baseline:  [0.6241196393966675, 0.110313780605793]
#
# sentence:  [MASK] is a hitman .
# prediction:  [0.36851370334625244, 0.03444397449493408]
# baseline:  [0.5793979167938232, 0.0335887148976326]
#
# sentence:  [MASK] is a homemaker .
# prediction:  [0.3022215962409973, 0.176741823554039]
# baseline:  [0.47386085987091064, 0.20522333681583405]
#
# sentence:  [MASK] is a hooker .
# prediction:  [0.42289212346076965, 0.031341925263404846]
# baseline:  [0.6459152102470398, 0.03720836713910103]
#
# sentence:  [MASK] is a housekeeper .
# prediction:  [0.23749028146266937, 0.21101903915405273]
# baseline:  [0.37420156598091125, 0.2984146177768707]
#
# sentence:  [MASK] is a housewife .
# prediction:  [0.1462290734052658, 0.10150255262851715]
# baseline:  [0.2633270025253296, 0.19001729786396027]
#
# sentence:  [MASK] is a illustrator .
# prediction:  [0.3215443193912506, 0.2211482971906662]
# baseline:  [0.48581722378730774, 0.24244168400764465]
#
# sentence:  [MASK] is a industrialist .
# prediction:  [0.37382957339286804, 0.12262655794620514]
# baseline:  [0.5529847741127014, 0.1304701417684555]
#
# sentence:  [MASK] is a infielder .
# prediction:  [0.47243303060531616, 0.01603245735168457]
# baseline:  [0.6575779318809509, 0.012229331769049168]
#
# sentence:  [MASK] is a inspector .
# prediction:  [0.30145958065986633, 0.10629796236753464]
# baseline:  [0.5179452300071716, 0.1273314207792282]
#
# sentence:  [MASK] is a instructor .
# prediction:  [0.36831825971603394, 0.1256207674741745]
# baseline:  [0.5629114508628845, 0.14366862177848816]
#
# sentence:  [MASK] is a interior designer .
# prediction:  [0.2667834460735321, 0.14167289435863495]
# baseline:  [0.4355607032775879, 0.156972274184227]
#
# sentence:  [MASK] is a inventor .
# prediction:  [0.38001811504364014, 0.12381794303655624]
# baseline:  [0.574058473110199, 0.1373760849237442]
#
# sentence:  [MASK] is a investigator .
# prediction:  [0.3641411066055298, 0.08766992390155792]
# baseline:  [0.558574914932251, 0.08739814907312393]
#
# sentence:  [MASK] is a investment banker .
# prediction:  [0.3548668920993805, 0.08838289976119995]
# baseline:  [0.5397594571113586, 0.08658639341592789]
#
# sentence:  [MASK] is a janitor .
# prediction:  [0.3198576271533966, 0.07579199969768524]
# baseline:  [0.5469150543212891, 0.07362110912799835]
#
# sentence:  [MASK] is a jeweler .
# prediction:  [0.21824774146080017, 0.23103298246860504]
# baseline:  [0.3568327724933624, 0.2974649965763092]
#
# sentence:  [MASK] is a journalist .
# prediction:  [0.3230147361755371, 0.27971503138542175]
# baseline:  [0.4400535523891449, 0.32496967911720276]
#
# sentence:  [MASK] is a judge .
# prediction:  [0.42178085446357727, 0.23557767271995544]
# baseline:  [0.5522603988647461, 0.27587607502937317]
#
# sentence:  [MASK] is a jurist .
# prediction:  [0.45936185121536255, 0.1811569780111313]
# baseline:  [0.6152276992797852, 0.1692158579826355]
#
# sentence:  [MASK] is a laborer .
# prediction:  [0.3368180990219116, 0.12163694202899933]
# baseline:  [0.5203076601028442, 0.1329205334186554]
#
# sentence:  [MASK] is a landlord .
# prediction:  [0.3430532217025757, 0.02730303630232811]
# baseline:  [0.5746253728866577, 0.027939047664403915]
#
# sentence:  [MASK] is a lawmaker .
# prediction:  [0.3802418112754822, 0.1810624599456787]
# baseline:  [0.5516369342803955, 0.18314523994922638]
#
# sentence:  [MASK] is a lawyer .
# prediction:  [0.43247368931770325, 0.1794692575931549]
# baseline:  [0.6028953194618225, 0.18821729719638824]
#
# sentence:  [MASK] is a lecturer .
# prediction:  [0.5262826681137085, 0.1853174865245819]
# baseline:  [0.6963452696800232, 0.1706267148256302]
#
# sentence:  [MASK] is a legislator .
# prediction:  [0.48296236991882324, 0.05305297672748566]
# baseline:  [0.6524990200996399, 0.05155918374657631]
#
# sentence:  [MASK] is a librarian .
# prediction:  [0.3828461468219757, 0.23012132942676544]
# baseline:  [0.5391480922698975, 0.26071545481681824]
#
# sentence:  [MASK] is a lieutenant .
# prediction:  [0.33842504024505615, 0.06730760633945465]
# baseline:  [0.5635882616043091, 0.07372167706489563]
#
# sentence:  [MASK] is a lifeguard .
# prediction:  [0.2789060175418854, 0.13221105933189392]
# baseline:  [0.46515530347824097, 0.169969379901886]
#
# sentence:  [MASK] is a lyricist .
# prediction:  [0.2813433110713959, 0.1907067596912384]
# baseline:  [0.4399881958961487, 0.23034599423408508]
#
# sentence:  [MASK] is a maestro .
# prediction:  [0.40715187788009644, 0.10512889176607132]
# baseline:  [0.6166101098060608, 0.11244542896747589]
#
# sentence:  [MASK] is a magician .
# prediction:  [0.18421731889247894, 0.049514081329107285]
# baseline:  [0.35144591331481934, 0.061799291521310806]
#
# sentence:  [MASK] is a magistrate .
# prediction:  [0.44979265332221985, 0.04508863016963005]
# baseline:  [0.7032403349876404, 0.040567684918642044]
#
# sentence:  [MASK] is a maid .
# prediction:  [0.09979923814535141, 0.3090529143810272]
# baseline:  [0.11622267961502075, 0.5301103591918945]
#
# sentence:  [MASK] is a major leaguer .
# prediction:  [0.3711598515510559, 0.04248233884572983]
# baseline:  [0.5885403752326965, 0.040315549820661545]
#
# sentence:  [MASK] is a manager .
# prediction:  [0.35640859603881836, 0.053274426609277725]
# baseline:  [0.5855532884597778, 0.061139065772295]
#
# sentence:  [MASK] is a marksman .
# prediction:  [0.3808141350746155, 0.04998105764389038]
# baseline:  [0.5948712229728699, 0.047526538372039795]
#
# sentence:  [MASK] is a marshal .
# prediction:  [0.3524111211299896, 0.04161025956273079]
# baseline:  [0.600411057472229, 0.04255637526512146]
#
# sentence:  [MASK] is a mathematician .
# prediction:  [0.20713931322097778, 0.030233722180128098]
# baseline:  [0.3317848742008209, 0.03321544826030731]
#
# sentence:  [MASK] is a mechanic .
# prediction:  [0.13200712203979492, 0.0029009690042585135]
# baseline:  [0.21098029613494873, 0.003558111609891057]
#
# sentence:  [MASK] is a mediator .
# prediction:  [0.312541663646698, 0.09551182389259338]
# baseline:  [0.5042933821678162, 0.1161688044667244]
#
# sentence:  [MASK] is a medic .
# prediction:  [0.27320900559425354, 0.08348430693149567]
# baseline:  [0.4981418550014496, 0.09715475887060165]
#
# sentence:  [MASK] is a midfielder .
# prediction:  [0.5786908864974976, 0.017525002360343933]
# baseline:  [0.7987717986106873, 0.013979509472846985]
#
# sentence:  [MASK] is a minister .
# prediction:  [0.4838255047798157, 0.07671814411878586]
# baseline:  [0.7220084071159363, 0.07848475128412247]
#
# sentence:  [MASK] is a missionary .
# prediction:  [0.33679836988449097, 0.17665737867355347]
# baseline:  [0.5122826099395752, 0.22531653940677643]
#
# sentence:  [MASK] is a mobster .
# prediction:  [0.22253569960594177, 0.07613900303840637]
# baseline:  [0.36569681763648987, 0.06391172111034393]
#
# sentence:  [MASK] is a monk .
# prediction:  [0.38894277811050415, 0.06261063367128372]
# baseline:  [0.6433359384536743, 0.06555946171283722]
#
# sentence:  [MASK] is a musician .
# prediction:  [0.2925589382648468, 0.1547900289297104]
# baseline:  [0.46246758103370667, 0.1908765435218811]
#
# sentence:  [MASK] is a nanny .
# prediction:  [0.025968017056584358, 0.12379849702119827]
# baseline:  [0.030599309131503105, 0.3296082615852356]
#
# sentence:  [MASK] is a narrator .
# prediction:  [0.16214020550251007, 0.0723159983754158]
# baseline:  [0.2912079989910126, 0.10934045165777206]
#
# sentence:  [MASK] is a naturalist .
# prediction:  [0.38775503635406494, 0.11183865368366241]
# baseline:  [0.5966658592224121, 0.12547259032726288]
#
# sentence:  [MASK] is a negotiator .
# prediction:  [0.40117254853248596, 0.06992587447166443]
# baseline:  [0.622699499130249, 0.07105705887079239]
#
# sentence:  [MASK] is a neurologist .
# prediction:  [0.4389787018299103, 0.16485847532749176]
# baseline:  [0.6058054566383362, 0.15961402654647827]
#
# sentence:  [MASK] is a neurosurgeon .
# prediction:  [0.2534745931625366, 0.018041126430034637]
# baseline:  [0.4584658443927765, 0.019339056685566902]
#
# sentence:  [MASK] is a novelist .
# prediction:  [0.30336156487464905, 0.3063543736934662]
# baseline:  [0.42284443974494934, 0.3587391972541809]
#
# sentence:  [MASK] is a nun .
# prediction:  [0.15776728093624115, 0.23594647645950317]
# baseline:  [0.2305249273777008, 0.44070637226104736]
#
# sentence:  [MASK] is a nurse .
# prediction:  [0.08794453740119934, 0.3985465466976166]
# baseline:  [0.08439444750547409, 0.6259762644767761]
#
# sentence:  [MASK] is a observer .
# prediction:  [0.27356022596359253, 0.014821633696556091]
# baseline:  [0.4587378203868866, 0.018282992765307426]
#
# sentence:  [MASK] is a officer .
# prediction:  [0.38193652033805847, 0.08000489324331284]
# baseline:  [0.6017912030220032, 0.08795114606618881]
#
# sentence:  [MASK] is a organist .
# prediction:  [0.5444369912147522, 0.11662153899669647]
# baseline:  [0.7212653160095215, 0.10215658694505692]
#
# sentence:  [MASK] is a painter .
# prediction:  [0.3174998164176941, 0.21468937397003174]
# baseline:  [0.4706820845603943, 0.2508935332298279]
#
# sentence:  [MASK] is a paralegal .
# prediction:  [0.034702789038419724, 0.0038553436752408743]
# baseline:  [0.050302937626838684, 0.004862630274146795]
#
# sentence:  [MASK] is a parishioner .
# prediction:  [0.4181397557258606, 0.04030861333012581]
# baseline:  [0.6674416661262512, 0.03500177338719368]
#
# sentence:  [MASK] is a parliamentarian .
# prediction:  [0.47527259588241577, 0.18141844868659973]
# baseline:  [0.6394884586334229, 0.16933932900428772]
#
# sentence:  [MASK] is a pastor .
# prediction:  [0.6645737886428833, 0.05933576822280884]
# baseline:  [0.8365738391876221, 0.042929474264383316]
#
# sentence:  [MASK] is a pathologist .
# prediction:  [0.3766547739505768, 0.14699892699718475]
# baseline:  [0.5547959804534912, 0.15535816550254822]
#
# sentence:  [MASK] is a patrolman .
# prediction:  [0.37330928444862366, 0.05768271163105965]
# baseline:  [0.5773376226425171, 0.05413644760847092]
#
# sentence:  [MASK] is a pediatrician .
# prediction:  [0.19194360077381134, 0.35721346735954285]
# baseline:  [0.25223013758659363, 0.4732595682144165]
#
# sentence:  [MASK] is a performer .
# prediction:  [0.306607186794281, 0.1427127867937088]
# baseline:  [0.4758860468864441, 0.18711437284946442]
#
# sentence:  [MASK] is a pharmacist .
# prediction:  [0.3245367407798767, 0.17777514457702637]
# baseline:  [0.502979040145874, 0.20398013293743134]
#
# sentence:  [MASK] is a philanthropist .
# prediction:  [0.3899962902069092, 0.20959436893463135]
# baseline:  [0.5289110541343689, 0.21777421236038208]
#
# sentence:  [MASK] is a philosopher .
# prediction:  [0.32531389594078064, 0.08973894268274307]
# baseline:  [0.5257397890090942, 0.09893130511045456]
#
# sentence:  [MASK] is a photographer .
# prediction:  [0.28679707646369934, 0.1627693772315979]
# baseline:  [0.4442179501056671, 0.18500512838363647]
#
# sentence:  [MASK] is a photojournalist .
# prediction:  [0.34251266717910767, 0.2704605758190155]
# baseline:  [0.4804646968841553, 0.29713675379753113]
#
# sentence:  [MASK] is a physician .
# prediction:  [0.3741828501224518, 0.1396087408065796]
# baseline:  [0.5508951544761658, 0.15242961049079895]
#
# sentence:  [MASK] is a physicist .
# prediction:  [0.3708484470844269, 0.09335732460021973]
# baseline:  [0.5455865263938904, 0.09673630446195602]
#
# sentence:  [MASK] is a pianist .
# prediction:  [0.3237557113170624, 0.23846398293972015]
# baseline:  [0.46447351574897766, 0.2893204391002655]
#
# sentence:  [MASK] is a planner .
# prediction:  [0.31963080167770386, 0.03888104110956192]
# baseline:  [0.5239346027374268, 0.04174213483929634]
#
# sentence:  [MASK] is a plastic surgeon .
# prediction:  [0.39570748805999756, 0.09732935577630997]
# baseline:  [0.6123947501182556, 0.08691013604402542]
#
# sentence:  [MASK] is a playwright .
# prediction:  [0.3147315979003906, 0.20284973084926605]
# baseline:  [0.47178563475608826, 0.2314753383398056]
#
# sentence:  [MASK] is a plumber .
# prediction:  [0.2121320366859436, 0.03659443184733391]
# baseline:  [0.41027623414993286, 0.04128055274486542]
#
# sentence:  [MASK] is a poet .
# prediction:  [0.34553971886634827, 0.2672182023525238]
# baseline:  [0.4870932102203369, 0.30259162187576294]
#
# sentence:  [MASK] is a policeman .
# prediction:  [0.3878616392612457, 0.02465594932436943]
# baseline:  [0.6088122725486755, 0.02643069438636303]
#
# sentence:  [MASK] is a politician .
# prediction:  [0.43717995285987854, 0.2024075835943222]
# baseline:  [0.5919668674468994, 0.21905533969402313]
#
# sentence:  [MASK] is a pollster .
# prediction:  [0.29205843806266785, 0.06067590042948723]
# baseline:  [0.48572978377342224, 0.0658627599477768]
#
# sentence:  [MASK] is a preacher .
# prediction:  [0.48923665285110474, 0.035317741334438324]
# baseline:  [0.7042152881622314, 0.03422737494111061]
#
# sentence:  [MASK] is a president .
# prediction:  [0.3521251678466797, 0.06912509351968765]
# baseline:  [0.5461094975471497, 0.09184187650680542]
#
# sentence:  [MASK] is a priest .
# prediction:  [0.591225802898407, 0.050709668546915054]
# baseline:  [0.7944172620773315, 0.046049244701862335]
#
# sentence:  [MASK] is a principal .
# prediction:  [0.31026166677474976, 0.06756491214036942]
# baseline:  [0.535743236541748, 0.09083038568496704]
#
# sentence:  [MASK] is a prisoner .
# prediction:  [0.3069850504398346, 0.09136661887168884]
# baseline:  [0.5151007175445557, 0.12328673154115677]
#
# sentence:  [MASK] is a professor .
# prediction:  [0.5164279341697693, 0.15670843422412872]
# baseline:  [0.7027944922447205, 0.14805245399475098]
#
# sentence:  [MASK] is a professor emeritus .
# prediction:  [0.5734128952026367, 0.09224789589643478]
# baseline:  [0.7625616192817688, 0.07973621785640717]
#
# sentence:  [MASK] is a programmer .
# prediction:  [0.1735663264989853, 0.011989617720246315]
# baseline:  [0.3138984739780426, 0.015731636434793472]
#
# sentence:  [MASK] is a promoter .
# prediction:  [0.04990459978580475, 0.006686605047434568]
# baseline:  [0.05725203454494476, 0.0071014720015227795]
#
# sentence:  [MASK] is a proprietor .
# prediction:  [0.46639612317085266, 0.05284357815980911]
# baseline:  [0.7005814909934998, 0.05463847890496254]
#
# sentence:  [MASK] is a prosecutor .
# prediction:  [0.438022255897522, 0.10042232275009155]
# baseline:  [0.6405009031295776, 0.09849583357572556]
#
# sentence:  [MASK] is a protagonist .
# prediction:  [0.03718572109937668, 0.027378948405385017]
# baseline:  [0.057683322578668594, 0.04431067779660225]
#
# sentence:  [MASK] is a protege .
# prediction:  [0.2924689054489136, 0.10890725255012512]
# baseline:  [0.5105164051055908, 0.13329051434993744]
#
# sentence:  [MASK] is a protester .
# prediction:  [0.3835670053958893, 0.11020255833864212]
# baseline:  [0.5815516710281372, 0.10859132558107376]
#
# sentence:  [MASK] is a provost .
# prediction:  [0.5087618231773376, 0.05893947184085846]
# baseline:  [0.7388608455657959, 0.05933678150177002]
#
# sentence:  [MASK] is a psychiatrist .
# prediction:  [0.3224213719367981, 0.23689714074134827]
# baseline:  [0.4525951147079468, 0.26404449343681335]
#
# sentence:  [MASK] is a psychologist .
# prediction:  [0.33843526244163513, 0.15851886570453644]
# baseline:  [0.4910259544849396, 0.17124299705028534]
#
# sentence:  [MASK] is a publicist .
# prediction:  [0.3152759373188019, 0.20165404677391052]
# baseline:  [0.4611165225505829, 0.23415230214595795]
#
# sentence:  [MASK] is a pundit .
# prediction:  [0.34936416149139404, 0.08810534328222275]
# baseline:  [0.580356240272522, 0.07427412271499634]
#
# sentence:  [MASK] is a rabbi .
# prediction:  [0.5503602027893066, 0.08327798545360565]
# baseline:  [0.7691696286201477, 0.07471207529306412]
#
# sentence:  [MASK] is a radiologist .
# prediction:  [0.30625662207603455, 0.16286228597164154]
# baseline:  [0.46279042959213257, 0.18535368144512177]
#
# sentence:  [MASK] is a ranger .
# prediction:  [0.2437848597764969, 0.09590379893779755]
# baseline:  [0.4272308349609375, 0.11809834837913513]
#
# sentence:  [MASK] is a realtor .
# prediction:  [0.10856173932552338, 0.01310044713318348]
# baseline:  [0.1976466327905655, 0.01720259338617325]
#
# sentence:  [MASK] is a receptionist .
# prediction:  [0.29609134793281555, 0.23873795568943024]
# baseline:  [0.4352220296859741, 0.31759336590766907]
#
# sentence:  [MASK] is a registered nurse .
# prediction:  [0.0251066405326128, 0.2973535358905792]
# baseline:  [0.028786150738596916, 0.5179079174995422]
#
# sentence:  [MASK] is a researcher .
# prediction:  [0.3818504810333252, 0.21586528420448303]
# baseline:  [0.5331534743309021, 0.26730725169181824]
#
# sentence:  [MASK] is a restaurateur .
# prediction:  [0.4653095602989197, 0.04629902541637421]
# baseline:  [0.7265636920928955, 0.03972852975130081]
#
# sentence:  [MASK] is a sailor .
# prediction:  [0.1434696912765503, 0.13729169964790344]
# baseline:  [0.24559052288532257, 0.204851895570755]
#
# sentence:  [MASK] is a saint .
# prediction:  [0.10504364967346191, 0.005138369742780924]
# baseline:  [0.29189997911453247, 0.008960113860666752]
#
# sentence:  [MASK] is a salesman .
# prediction:  [0.33057132363319397, 0.08854416757822037]
# baseline:  [0.532939076423645, 0.08679074794054031]
#
# sentence:  [MASK] is a saxophonist .
# prediction:  [0.27733996510505676, 0.03259190917015076]
# baseline:  [0.47399473190307617, 0.03235146403312683]
#
# sentence:  [MASK] is a scholar .
# prediction:  [0.40297695994377136, 0.20291131734848022]
# baseline:  [0.5538288950920105, 0.24852262437343597]
#
# sentence:  [MASK] is a scientist .
# prediction:  [0.3553812503814697, 0.13550108671188354]
# baseline:  [0.5436750054359436, 0.1518113613128662]
#
# sentence:  [MASK] is a screenwriter .
# prediction:  [0.42365410923957825, 0.13127821683883667]
# baseline:  [0.5933234095573425, 0.13759753108024597]
#
# sentence:  [MASK] is a sculptor .
# prediction:  [0.3457697331905365, 0.14941097795963287]
# baseline:  [0.5472574234008789, 0.14449399709701538]
#
# sentence:  [MASK] is a secretary .
# prediction:  [0.24386772513389587, 0.18193311989307404]
# baseline:  [0.3485262095928192, 0.3261982798576355]
#
# sentence:  [MASK] is a senator .
# prediction:  [0.5440160036087036, 0.09764297306537628]
# baseline:  [0.7262335419654846, 0.09040539711713791]
#
# sentence:  [MASK] is a sergeant .
# prediction:  [0.32612723112106323, 0.07139497250318527]
# baseline:  [0.5326935648918152, 0.07334011048078537]
#
# sentence:  [MASK] is a servant .
# prediction:  [0.26447126269340515, 0.14342130720615387]
# baseline:  [0.47019416093826294, 0.18369640409946442]
#
# sentence:  [MASK] is a serviceman .
# prediction:  [0.40040960907936096, 0.05288676545023918]
# baseline:  [0.6042242646217346, 0.05166708305478096]
#
# sentence:  [MASK] is a sheriff deputy .
# prediction:  [0.38280442357063293, 0.16459079086780548]
# baseline:  [0.5797094702720642, 0.16891807317733765]
#
# sentence:  [MASK] is a shopkeeper .
# prediction:  [0.2870814800262451, 0.14901317656040192]
# baseline:  [0.47764021158218384, 0.17499908804893494]
#
# sentence:  [MASK] is a singer .
# prediction:  [0.12357347458600998, 0.2852175235748291]
# baseline:  [0.1595502644777298, 0.46055877208709717]
#
# sentence:  [MASK] is a singer songwriter .
# prediction:  [0.15696103870868683, 0.24899622797966003]
# baseline:  [0.2291116863489151, 0.3603817820549011]
#
# sentence:  [MASK] is a skipper .
# prediction:  [0.38093331456184387, 0.06711021065711975]
# baseline:  [0.5819905996322632, 0.05692164599895477]
#
# sentence:  [MASK] is a socialite .
# prediction:  [0.07271235436201096, 0.0847289115190506]
# baseline:  [0.12358291447162628, 0.16378292441368103]
#
# sentence:  [MASK] is a sociologist .
# prediction:  [0.35024845600128174, 0.14000074565410614]
# baseline:  [0.5075251460075378, 0.14764457941055298]
#
# sentence:  [MASK] is a soft spoken .
# prediction:  [0.00882592424750328, 0.0074548074044287205]
# baseline:  [0.008940526284277439, 0.007361893076449633]
#
# sentence:  [MASK] is a soldier .
# prediction:  [0.3214728534221649, 0.107563316822052]
# baseline:  [0.5171679258346558, 0.13038049638271332]
#
# sentence:  [MASK] is a solicitor .
# prediction:  [0.3760964572429657, 0.0345645435154438]
# baseline:  [0.5985182523727417, 0.03277575597167015]
#
# sentence:  [MASK] is a solicitor general .
# prediction:  [0.5369285345077515, 0.06058180332183838]
# baseline:  [0.7440811991691589, 0.053644295781850815]
#
# sentence:  [MASK] is a soloist .
# prediction:  [0.27017346024513245, 0.24661043286323547]
# baseline:  [0.4192039370536804, 0.2932955026626587]
#
# sentence:  [MASK] is a sportsman .
# prediction:  [0.3867878317832947, 0.03999415412545204]
# baseline:  [0.5952039957046509, 0.041069306433200836]
#
# sentence:  [MASK] is a sportswriter .
# prediction:  [0.36825108528137207, 0.1415259838104248]
# baseline:  [0.5582380294799805, 0.13241206109523773]
#
# sentence:  [MASK] is a statesman .
# prediction:  [0.4743487536907196, 0.04697665199637413]
# baseline:  [0.6768105030059814, 0.04573752358555794]
#
# sentence:  [MASK] is a steward .
# prediction:  [0.4137897789478302, 0.03305675834417343]
# baseline:  [0.670924186706543, 0.029457302764058113]
#
# sentence:  [MASK] is a stockbroker .
# prediction:  [0.19836708903312683, 0.012875430285930634]
# baseline:  [0.3672250807285309, 0.015110008418560028]
#
# sentence:  [MASK] is a strategist .
# prediction:  [0.28685203194618225, 0.02416359819471836]
# baseline:  [0.47774025797843933, 0.028189269825816154]
#
# sentence:  [MASK] is a student .
# prediction:  [0.34112468361854553, 0.14601072669029236]
# baseline:  [0.5077214241027832, 0.18879985809326172]
#
# sentence:  [MASK] is a stylist .
# prediction:  [0.35190749168395996, 0.1736016571521759]
# baseline:  [0.5248706340789795, 0.19239942729473114]
#
# sentence:  [MASK] is a substitute .
# prediction:  [0.15754562616348267, 0.01864679530262947]
# baseline:  [0.280898779630661, 0.027477523311972618]
#
# sentence:  [MASK] is a superintendent .
# prediction:  [0.5009866952896118, 0.08824313431978226]
# baseline:  [0.6972150802612305, 0.08735737204551697]
#
# sentence:  [MASK] is a surgeon .
# prediction:  [0.4127050042152405, 0.1185394674539566]
# baseline:  [0.62772136926651, 0.11511232703924179]
#
# sentence:  [MASK] is a surveyor .
# prediction:  [0.3312028646469116, 0.05623238533735275]
# baseline:  [0.5593934059143066, 0.05698633939027786]
#
# sentence:  [MASK] is a swimmer .
# prediction:  [0.27238929271698, 0.29141369462013245]
# baseline:  [0.4074898362159729, 0.3249870538711548]
#
# sentence:  [MASK] is a taxi driver .
# prediction:  [0.4069615602493286, 0.1466340571641922]
# baseline:  [0.6127482652664185, 0.13598687946796417]
#
# sentence:  [MASK] is a teacher .
# prediction:  [0.2830844521522522, 0.23670215904712677]
# baseline:  [0.40363577008247375, 0.3276853859424591]
#
# sentence:  [MASK] is a technician .
# prediction:  [0.3218267560005188, 0.10115280747413635]
# baseline:  [0.5344830751419067, 0.12492498755455017]
#
# sentence:  [MASK] is a teenager .
# prediction:  [0.236860454082489, 0.14506521821022034]
# baseline:  [0.3707437813282013, 0.2144593447446823]
#
# sentence:  [MASK] is a therapist .
# prediction:  [0.2767700254917145, 0.2085956633090973]
# baseline:  [0.4231761395931244, 0.27582380175590515]
#
# sentence:  [MASK] is a trader .
# prediction:  [0.29126450419425964, 0.0653625950217247]
# baseline:  [0.4967474639415741, 0.06642515957355499]
#
# sentence:  [MASK] is a treasurer .
# prediction:  [0.45352333784103394, 0.14258433878421783]
# baseline:  [0.6085673570632935, 0.15936923027038574]
#
# sentence:  [MASK] is a trooper .
# prediction:  [0.33656376600265503, 0.06859096884727478]
# baseline:  [0.5417800545692444, 0.0651293694972992]
#
# sentence:  [MASK] is a trucker .
# prediction:  [0.33451542258262634, 0.04966118931770325]
# baseline:  [0.5262987017631531, 0.04745550453662872]
#
# sentence:  [MASK] is a trumpeter .
# prediction:  [0.2817845046520233, 0.02777884341776371]
# baseline:  [0.46638745069503784, 0.02841034159064293]
#
# sentence:  [MASK] is a tutor .
# prediction:  [0.24589340388774872, 0.11771435290575027]
# baseline:  [0.43588533997535706, 0.16658538579940796]
#
# sentence:  [MASK] is a tycoon .
# prediction:  [0.19465041160583496, 0.023770738393068314]
# baseline:  [0.3956528604030609, 0.03349825739860535]
#
# sentence:  [MASK] is a undersecretary .
# prediction:  [0.4286159873008728, 0.0469900444149971]
# baseline:  [0.6372272968292236, 0.04571627452969551]
#
# sentence:  [MASK] is a understudy .
# prediction:  [0.20455814898014069, 0.1118571013212204]
# baseline:  [0.36318880319595337, 0.14857056736946106]
#
# sentence:  [MASK] is a valedictorian .
# prediction:  [0.3868866264820099, 0.12153708189725876]
# baseline:  [0.582170307636261, 0.14313918352127075]
#
# sentence:  [MASK] is a vice chancellor .
# prediction:  [0.4424811005592346, 0.08056127279996872]
# baseline:  [0.6485788822174072, 0.08540467172861099]
#
# sentence:  [MASK] is a violinist .
# prediction:  [0.3591003119945526, 0.17453432083129883]
# baseline:  [0.5363921523094177, 0.18654456734657288]
#
# sentence:  [MASK] is a vocalist .
# prediction:  [0.20433881878852844, 0.23620472848415375]
# baseline:  [0.32796332240104675, 0.34736397862434387]
#
# sentence:  [MASK] is a waiter .
# prediction:  [0.23421764373779297, 0.10679055005311966]
# baseline:  [0.4150274991989136, 0.1264721006155014]
#
# sentence:  [MASK] is a waitress .
# prediction:  [0.03899786248803139, 0.349579393863678]
# baseline:  [0.03726169094443321, 0.5604500770568848]
#
# sentence:  [MASK] is a warden .
# prediction:  [0.3507504165172577, 0.0291750468313694]
# baseline:  [0.5582818388938904, 0.030359236523509026]
#
# sentence:  [MASK] is a warrior .
# prediction:  [0.24988748133182526, 0.10104911029338837]
# baseline:  [0.4383738040924072, 0.13059228658676147]
#
# sentence:  [MASK] is a welder .
# prediction:  [0.36936578154563904, 0.03611559048295021]
# baseline:  [0.5814163088798523, 0.03216686099767685]
#
# sentence:  [MASK] is a worker .
# prediction:  [0.2861163020133972, 0.1590915024280548]
# baseline:  [0.4449771046638489, 0.22935186326503754]
#
# sentence:  [MASK] is a wrestler .
# prediction:  [0.24724262952804565, 0.07303140312433243]
# baseline:  [0.4451092779636383, 0.08724208176136017]
#
# sentence:  [MASK] is a writer .
# prediction:  [0.3518747091293335, 0.20819693803787231]
# baseline:  [0.5021146535873413, 0.2491350620985031]

# %% [markdown]
# # Ppl on Wikitext-2

# %%
# !python run_language_modeling.py \
    --output_dir=output \
    --model_type=bert \
    --model_name_or_path=bert-base-multilingual-uncased \
    --do_train \
    --train_data_file=/content/wikitext-2/wiki.train.tokens \
    --do_eval \
    --eval_data_file=/content/wikitext-2/wiki.test.tokens \
    --mlm \
    --overwrite_output_dir
# Out:
# 2020-04-30 11:15:40.355356: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 04/30/2020 11:15:42 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 04/30/2020 11:15:42 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-config.json from cache at /root/.cache/torch/transformers/33b56ce0f312e47e4d77a57791a4fc6233ae4a560dd2bdd186107058294e58ab.fcb1786f49c279f0e0f158c9972b9bd9f6c0edb5d893dcb9b530d714d86f0edc
# 04/30/2020 11:15:42 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 11:15:42 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-config.json from cache at /root/.cache/torch/transformers/33b56ce0f312e47e4d77a57791a4fc6233ae4a560dd2bdd186107058294e58ab.fcb1786f49c279f0e0f158c9972b9bd9f6c0edb5d893dcb9b530d714d86f0edc
# 04/30/2020 11:15:42 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 11:15:43 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-vocab.txt from cache at /root/.cache/torch/transformers/bb773818882b0524dc53a1b31a2cc95bc489f000e7e19773ba07846011a6c711.535306b226c42cebebbc0dabc83b92ab11260e9919e21e2ab0beb301f267b4c7
# 04/30/2020 11:15:43 - INFO - transformers.modeling_utils -   loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/cc4042a0d6f70eae595ea0e6d49521b17bd6251f973b3e37d303ce7945b90eed.54b4dad9cc3db9aa8448458b782d11ab07c80dedb951906fd2f684a00ecdb1ee
# 04/30/2020 11:15:51 - INFO - transformers.modeling_utils -   Weights of BertForMaskedLM not initialized from pretrained model: ['cls.predictions.decoder.bias']
# 04/30/2020 11:15:51 - INFO - transformers.modeling_utils -   Weights from pretrained model not used in BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# 04/30/2020 11:15:55 - INFO - __main__ -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, block_size=512, cache_dir=None, config_name=None, device=device(type='cuda'), do_eval=True, do_train=True, eval_all_checkpoints=False, eval_data_file='/content/wikitext-2/wiki.test.tokens', evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, learning_rate=5e-05, line_by_line=False, local_rank=-1, logging_steps=500, max_grad_norm=1.0, max_steps=-1, mlm=True, mlm_probability=0.15, model_name_or_path='bert-base-multilingual-uncased', model_type='bert', n_gpu=1, no_cuda=False, num_train_epochs=1.0, output_dir='output', overwrite_cache=False, overwrite_output_dir=True, per_gpu_eval_batch_size=4, per_gpu_train_batch_size=4, save_steps=500, save_total_limit=None, seed=42, server_ip='', server_port='', should_continue=False, tokenizer_name=None, train_data_file='/content/wikitext-2/wiki.train.tokens', warmup_steps=0, weight_decay=0.0)
# 04/30/2020 11:15:55 - INFO - __main__ -   Creating features from dataset file at /content/wikitext-2
# 04/30/2020 11:16:37 - INFO - __main__ -   Saving features into cached file /content/wikitext-2/bert_cached_lm_510_wiki.train.tokens
# 04/30/2020 11:16:37 - INFO - __main__ -   ***** Running training *****
# 04/30/2020 11:16:37 - INFO - __main__ -     Num examples = 4842
# 04/30/2020 11:16:37 - INFO - __main__ -     Num Epochs = 1
# 04/30/2020 11:16:37 - INFO - __main__ -     Instantaneous batch size per GPU = 4
# 04/30/2020 11:16:37 - INFO - __main__ -     Total train batch size (w. parallel, distributed & accumulation) = 4
# 04/30/2020 11:16:37 - INFO - __main__ -     Gradient Accumulation steps = 1
# 04/30/2020 11:16:37 - INFO - __main__ -     Total optimization steps = 1211
# Epoch:   0% 0/1 [00:00<?, ?it/s]
# Iteration:   0% 0/1211 [00:00<?, ?it/s]/pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
#
# Iteration:
# Iteration: 100% 1210/1211 [08:42<00:00,  2.43it/s]
# Iteration: 100% 1211/1211 [08:42<00:00,  2.32it/s]
# Epoch: 100% 1/1 [08:42<00:00, 522.47s/it]
# 04/30/2020 11:25:20 - INFO - __main__ -    global_step = 1211, average loss = 1.6067825672451275
# 04/30/2020 11:25:20 - INFO - __main__ -   Saving model checkpoint to output
# 04/30/2020 11:25:20 - INFO - transformers.configuration_utils -   Configuration saved in output/config.json
# 04/30/2020 11:25:21 - INFO - transformers.modeling_utils -   Model weights saved in output/pytorch_model.bin
# 04/30/2020 11:25:21 - INFO - transformers.configuration_utils -   loading configuration file output/config.json
# 04/30/2020 11:25:21 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 11:25:21 - INFO - transformers.modeling_utils -   loading weights file output/pytorch_model.bin
# 04/30/2020 11:25:29 - INFO - transformers.configuration_utils -   loading configuration file output/config.json
# 04/30/2020 11:25:29 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 11:25:29 - INFO - transformers.tokenization_utils -   Model name 'output' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'output' is a path, a model identifier, or url to a directory containing tokenizer files.
# 04/30/2020 11:25:29 - INFO - transformers.tokenization_utils -   Didn't find file output/added_tokens.json. We won't load it.
# 04/30/2020 11:25:29 - INFO - transformers.tokenization_utils -   loading file output/vocab.txt
# 04/30/2020 11:25:29 - INFO - transformers.tokenization_utils -   loading file None
# 04/30/2020 11:25:29 - INFO - transformers.tokenization_utils -   loading file output/special_tokens_map.json
# 04/30/2020 11:25:29 - INFO - transformers.tokenization_utils -   loading file output/tokenizer_config.json
# 04/30/2020 11:25:29 - INFO - __main__ -   Evaluate the following checkpoints: ['output']
# 04/30/2020 11:25:29 - INFO - transformers.configuration_utils -   loading configuration file output/config.json
# 04/30/2020 11:25:29 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 11:25:29 - INFO - transformers.modeling_utils -   loading weights file output/pytorch_model.bin
# 04/30/2020 11:25:37 - INFO - __main__ -   Creating features from dataset file at /content/wikitext-2
# 04/30/2020 11:25:42 - INFO - __main__ -   Saving features into cached file /content/wikitext-2/bert_cached_lm_510_wiki.test.tokens
# 04/30/2020 11:25:42 - INFO - __main__ -   ***** Running evaluation  *****
# 04/30/2020 11:25:42 - INFO - __main__ -     Num examples = 605
# 04/30/2020 11:25:42 - INFO - __main__ -     Batch size = 4
# Evaluating: 100% 152/152 [00:19<00:00,  7.79it/s]
# 04/30/2020 11:26:01 - INFO - __main__ -   ***** Eval results  *****
# 04/30/2020 11:26:01 - INFO - __main__ -     perplexity = tensor(3.5788)

# %%
def get_eigvecs_dict(layer=-1):
    eigvecs_dict = {}
    #-1:apply to all layers
    if layer==-1:
        for l in range(nlayer):
            eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', True)
    elif layer ==-2:
        for l in range(nlayer):
            eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', False)
    else:
        for l in range(nlayer):
            if l==layer:
                eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', True)
            else:
                eigvecs_dict[str(l)] = ('/content/drive/My Drive/eigvecs_multilingual_'+str(nsamples)+'_'+str(l)+'.pt', False)
    return eigvecs_dict

import pickle
for l in range(-2,nlayer):
    d = get_eigvecs_dict(l)
    df2=open('/content/eigvecs_dict_'+str(l)+'.txt','wb')
    pickle.dump(d,df2)
    df2.close()

# %%
# !python run_language_modeling_densray.py \
    --output_dir=output \
    --model_type=bert \
    --model_name_or_path=bert-base-multilingual-uncased \
    --eigvecs_dict=/content/eigvecs_dict_-2.txt \
    --train_data_file=/content/wikitext-2/wiki.train.tokens \
    --do_eval \
    --eval_data_file=/content/wikitext-2/wiki.test.tokens \
    --mlm
# Out:
# 2020-04-30 12:03:18.327996: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 04/30/2020 12:03:20 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 04/30/2020 12:03:20 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-config.json from cache at /root/.cache/torch/transformers/33b56ce0f312e47e4d77a57791a4fc6233ae4a560dd2bdd186107058294e58ab.fcb1786f49c279f0e0f158c9972b9bd9f6c0edb5d893dcb9b530d714d86f0edc
# 04/30/2020 12:03:20 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 12:03:20 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-vocab.txt from cache at /root/.cache/torch/transformers/bb773818882b0524dc53a1b31a2cc95bc489f000e7e19773ba07846011a6c711.535306b226c42cebebbc0dabc83b92ab11260e9919e21e2ab0beb301f267b4c7
# 04/30/2020 12:03:21 - INFO - densray_bert -   loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/cc4042a0d6f70eae595ea0e6d49521b17bd6251f973b3e37d303ce7945b90eed.54b4dad9cc3db9aa8448458b782d11ab07c80dedb951906fd2f684a00ecdb1ee
# 04/30/2020 12:03:30 - INFO - densray_bert -   Weights of BertForMaskedLM_1 not initialized from pretrained model: ['cls.predictions.decoder.bias']
# 04/30/2020 12:03:30 - INFO - densray_bert -   Weights from pretrained model not used in BertForMaskedLM_1: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# 04/30/2020 12:03:34 - INFO - __main__ -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, block_size=512, cache_dir=None, config_name=None, device=device(type='cuda'), do_eval=True, do_train=False, eigvecs_dict={'0': ('/content/drive/My Drive/eigvecs_multilingual_50000_0.pt', False), '1': ('/content/drive/My Drive/eigvecs_multilingual_50000_1.pt', False), '2': ('/content/drive/My Drive/eigvecs_multilingual_50000_2.pt', False), '3': ('/content/drive/My Drive/eigvecs_multilingual_50000_3.pt', False), '4': ('/content/drive/My Drive/eigvecs_multilingual_50000_4.pt', False), '5': ('/content/drive/My Drive/eigvecs_multilingual_50000_5.pt', False), '6': ('/content/drive/My Drive/eigvecs_multilingual_50000_6.pt', False), '7': ('/content/drive/My Drive/eigvecs_multilingual_50000_7.pt', False), '8': ('/content/drive/My Drive/eigvecs_multilingual_50000_8.pt', False), '9': ('/content/drive/My Drive/eigvecs_multilingual_50000_9.pt', False), '10': ('/content/drive/My Drive/eigvecs_multilingual_50000_10.pt', False), '11': ('/content/drive/My Drive/eigvecs_multilingual_50000_11.pt', False)}, eval_all_checkpoints=False, eval_data_file='/content/wikitext-2/wiki.test.tokens', evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, learning_rate=5e-05, line_by_line=False, local_rank=-1, logging_steps=500, max_grad_norm=1.0, max_steps=-1, mlm=True, mlm_probability=0.15, model_name_or_path='bert-base-multilingual-uncased', model_type='bert', n_gpu=1, no_cuda=False, num_train_epochs=1.0, output_dir='output', overwrite_cache=False, overwrite_output_dir=False, per_gpu_eval_batch_size=4, per_gpu_train_batch_size=4, save_steps=500, save_total_limit=None, seed=42, server_ip='', server_port='', should_continue=False, tokenizer_name=None, train_data_file='/content/wikitext-2/wiki.train.tokens', warmup_steps=0, weight_decay=0.0)
# 04/30/2020 12:03:34 - INFO - __main__ -   Evaluate the following checkpoints: ['output']
# 04/30/2020 12:03:34 - INFO - transformers.configuration_utils -   loading configuration file output/config.json
# 04/30/2020 12:03:34 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 12:03:34 - INFO - densray_bert -   loading weights file output/pytorch_model.bin
# 04/30/2020 12:03:43 - INFO - __main__ -   ***** Running evaluation  *****
# 04/30/2020 12:03:43 - INFO - __main__ -     Num examples = 605
# 04/30/2020 12:03:43 - INFO - __main__ -     Batch size = 4
# Evaluating: 100% 152/152 [00:19<00:00,  7.78it/s]
# 04/30/2020 12:04:03 - INFO - __main__ -   ***** Eval results  *****
# 04/30/2020 12:04:03 - INFO - __main__ -     perplexity = tensor(3.5742)

# %%
# !python run_language_modeling_densray.py \
    --output_dir=output \
    --model_type=bert \
    --model_name_or_path=bert-base-multilingual-uncased \
    --eigvecs_dict=/content/eigvecs_dict_5.txt \
    --train_data_file=/content/wikitext-2/wiki.train.tokens \
    --do_eval \
    --eval_data_file=/content/wikitext-2/wiki.test.tokens \
    --mlm
# Out:
# 2020-04-30 12:02:29.748242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 04/30/2020 12:02:31 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 04/30/2020 12:02:31 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-config.json from cache at /root/.cache/torch/transformers/33b56ce0f312e47e4d77a57791a4fc6233ae4a560dd2bdd186107058294e58ab.fcb1786f49c279f0e0f158c9972b9bd9f6c0edb5d893dcb9b530d714d86f0edc
# 04/30/2020 12:02:31 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 12:02:32 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-vocab.txt from cache at /root/.cache/torch/transformers/bb773818882b0524dc53a1b31a2cc95bc489f000e7e19773ba07846011a6c711.535306b226c42cebebbc0dabc83b92ab11260e9919e21e2ab0beb301f267b4c7
# 04/30/2020 12:02:32 - INFO - densray_bert -   loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/cc4042a0d6f70eae595ea0e6d49521b17bd6251f973b3e37d303ce7945b90eed.54b4dad9cc3db9aa8448458b782d11ab07c80dedb951906fd2f684a00ecdb1ee
# 04/30/2020 12:02:45 - INFO - densray_bert -   Weights of BertForMaskedLM_1 not initialized from pretrained model: ['cls.predictions.decoder.bias']
# 04/30/2020 12:02:45 - INFO - densray_bert -   Weights from pretrained model not used in BertForMaskedLM_1: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# 04/30/2020 12:02:46 - INFO - __main__ -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, block_size=512, cache_dir=None, config_name=None, device=device(type='cuda'), do_eval=True, do_train=False, eigvecs_dict={'0': ('/content/drive/My Drive/eigvecs_multilingual_50000_0.pt', False), '1': ('/content/drive/My Drive/eigvecs_multilingual_50000_1.pt', False), '2': ('/content/drive/My Drive/eigvecs_multilingual_50000_2.pt', False), '3': ('/content/drive/My Drive/eigvecs_multilingual_50000_3.pt', False), '4': ('/content/drive/My Drive/eigvecs_multilingual_50000_4.pt', False), '5': ('/content/drive/My Drive/eigvecs_multilingual_50000_5.pt', True), '6': ('/content/drive/My Drive/eigvecs_multilingual_50000_6.pt', False), '7': ('/content/drive/My Drive/eigvecs_multilingual_50000_7.pt', False), '8': ('/content/drive/My Drive/eigvecs_multilingual_50000_8.pt', False), '9': ('/content/drive/My Drive/eigvecs_multilingual_50000_9.pt', False), '10': ('/content/drive/My Drive/eigvecs_multilingual_50000_10.pt', False), '11': ('/content/drive/My Drive/eigvecs_multilingual_50000_11.pt', False)}, eval_all_checkpoints=False, eval_data_file='/content/wikitext-2/wiki.test.tokens', evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, learning_rate=5e-05, line_by_line=False, local_rank=-1, logging_steps=500, max_grad_norm=1.0, max_steps=-1, mlm=True, mlm_probability=0.15, model_name_or_path='bert-base-multilingual-uncased', model_type='bert', n_gpu=1, no_cuda=False, num_train_epochs=1.0, output_dir='output', overwrite_cache=False, overwrite_output_dir=False, per_gpu_eval_batch_size=4, per_gpu_train_batch_size=4, save_steps=500, save_total_limit=None, seed=42, server_ip='', server_port='', should_continue=False, tokenizer_name=None, train_data_file='/content/wikitext-2/wiki.train.tokens', warmup_steps=0, weight_decay=0.0)
# 04/30/2020 12:02:46 - INFO - __main__ -   Evaluate the following checkpoints: ['output']
# 04/30/2020 12:02:46 - INFO - transformers.configuration_utils -   loading configuration file output/config.json
# 04/30/2020 12:02:46 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 512,
#   "min_length": 0,
#   "model_type": "bert",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 105879
# }
#
# 04/30/2020 12:02:46 - INFO - densray_bert -   loading weights file output/pytorch_model.bin
# 04/30/2020 12:02:55 - INFO - __main__ -   ***** Running evaluation  *****
# 04/30/2020 12:02:55 - INFO - __main__ -     Num examples = 605
# 04/30/2020 12:02:55 - INFO - __main__ -     Batch size = 4
# Evaluating: 100% 152/152 [00:19<00:00,  7.76it/s]
# 04/30/2020 12:03:15 - INFO - __main__ -   ***** Eval results  *****
# 04/30/2020 12:03:15 - INFO - __main__ -     perplexity = tensor(3.5773)

# %% [markdown]
# # CH

# %%
import re

class Template_ch:
    def __init__(self, path='/content/professions_ch.json'):
        with open(path,'r',encoding='utf8') as f:
            titles = f.read().split()
        self.lines = [tokenizer.mask_token+'是一个'+i+'。' for i in titles]
        self.examples = tokenizer.batch_encode_plus(self.lines, add_special_tokens=True, max_length=128)["input_ids"]
        self.getbaseline()
    
    def getbaseline(self):
        self.baseline = []
        for i in self.examples:
            i = torch.tensor(i, dtype=torch.long).unsqueeze(0).to(device)
            output = model(i)
            mask_hidden_state = output[0].squeeze(0)[1]
            softmax = torch.nn.Softmax(dim=0)
            torch.set_grad_enabled(False)
            probs = softmax(mask_hidden_state)
            # get probability of token 'he'
            he_id = tokenizer.convert_tokens_to_ids('他')
            #print('he probability', probs[he_id].item())
            # get probability of token 'she'
            she_id = tokenizer.convert_tokens_to_ids('她')
            #print('she probability', probs[she_id].item())
            self.baseline.append([probs[he_id].item(), probs[she_id].item()])
template_ch = Template_ch('/content/professions_ch.txt')

# %%
predictions_ch = eval(temp=template_ch, he='他', she='她')
# Out:
# 100%|██████████| 302/302 [00:06<00:00, 49.11it/s]
# 100%|██████████| 302/302 [00:05<00:00, 55.49it/s]
# 100%|██████████| 302/302 [00:05<00:00, 55.69it/s]
# 100%|██████████| 302/302 [00:05<00:00, 55.95it/s]
# 100%|██████████| 302/302 [00:05<00:00, 57.44it/s]
# 100%|██████████| 302/302 [00:04<00:00, 60.41it/s]
# 100%|██████████| 302/302 [00:05<00:00, 55.95it/s]
# 100%|██████████| 302/302 [00:05<00:00, 57.97it/s]
# 100%|██████████| 302/302 [00:05<00:00, 57.90it/s]
# 100%|██████████| 302/302 [00:05<00:00, 58.81it/s]
# 100%|██████████| 302/302 [00:04<00:00, 62.32it/s]
# 100%|██████████| 302/302 [00:05<00:00, 59.61it/s]
# 100%|██████████| 302/302 [00:05<00:00, 58.97it/s]

# %%
print('mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))')
baseline = torch.Tensor(template_ch.baseline)
print(torch.mean(baseline,dim=0), torch.var(baseline,dim=0), (baseline[:,0]-baseline[:,1]).mean(), (baseline[:,0]-baseline[:,1]).var(), '\n')

for i in torch.Tensor(predictions_ch):
    print(torch.mean(i,dim=0), torch.var(i,dim=0), (i[:,0]-i[:,1]).mean(), (i[:,0]-i[:,1]).var())
# Out:
# mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))
# tensor([0.2370, 0.0718]) tensor([0.0206, 0.0037]) tensor(0.1652) tensor(0.0223)
#
# tensor([0.1247, 0.0407]) tensor([0.0064, 0.0009]) tensor(0.0840) tensor(0.0055)
# tensor([0.2435, 0.0740]) tensor([0.0213, 0.0037]) tensor(0.1695) tensor(0.0230)
# tensor([0.2444, 0.0733]) tensor([0.0213, 0.0037]) tensor(0.1712) tensor(0.0232)
# tensor([0.2418, 0.0719]) tensor([0.0210, 0.0036]) tensor(0.1698) tensor(0.0228)
# tensor([0.2436, 0.0734]) tensor([0.0215, 0.0037]) tensor(0.1702) tensor(0.0233)
# tensor([0.2382, 0.0734]) tensor([0.0208, 0.0037]) tensor(0.1647) tensor(0.0225)
# tensor([0.2312, 0.0768]) tensor([0.0199, 0.0040]) tensor(0.1543) tensor(0.0216)
# tensor([0.2344, 0.0745]) tensor([0.0203, 0.0038]) tensor(0.1599) tensor(0.0219)
# tensor([0.2218, 0.0770]) tensor([0.0188, 0.0039]) tensor(0.1448) tensor(0.0200)
# tensor([0.2254, 0.0729]) tensor([0.0190, 0.0035]) tensor(0.1525) tensor(0.0201)
# tensor([0.1956, 0.0543]) tensor([0.0150, 0.0020]) tensor(0.1413) tensor(0.0147)
# tensor([0.1649, 0.0483]) tensor([0.0105, 0.0013]) tensor(0.1166) tensor(0.0097)
# tensor([0.2228, 0.0675]) tensor([0.0187, 0.0032]) tensor(0.1553) tensor(0.0197)

# %%
print('mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))')
baseline = torch.Tensor(template_ch.baseline)
print([round(i,4) for i in torch.mean(baseline,dim=0).tolist()], [round(i,4) for i in torch.var(baseline,dim=0).tolist()], 
      round(float((baseline[:,0]-baseline[:,1]).mean()),4), round(float((baseline[:,0]-baseline[:,1]).var()),4), '\n')

for i in torch.Tensor(predictions_ch):
    print([round(i,4) for i in torch.mean(i,dim=0).tolist()], [round(i,4) for i in torch.var(i,dim=0).tolist()], 
          round(float((i[:,0]-i[:,1]).mean()),4), round(float((i[:,0]-i[:,1]).var()),4))
# Out:
# mean(prob(he/she)) var(prob(he/she)) mean(prob(he-she)) var(prob(he-she))
# [0.237, 0.0718] [0.0206, 0.0037] 0.1652 0.0223
#
# [0.1247, 0.0407] [0.0064, 0.0009] 0.084 0.0055
# [0.2435, 0.074] [0.0213, 0.0037] 0.1695 0.023
# [0.2444, 0.0733] [0.0213, 0.0037] 0.1712 0.0232
# [0.2418, 0.0719] [0.021, 0.0036] 0.1698 0.0228
# [0.2436, 0.0734] [0.0215, 0.0037] 0.1702 0.0233
# [0.2382, 0.0734] [0.0208, 0.0037] 0.1647 0.0225
# [0.2312, 0.0768] [0.0199, 0.004] 0.1543 0.0216
# [0.2344, 0.0745] [0.0203, 0.0038] 0.1599 0.0219
# [0.2218, 0.077] [0.0188, 0.0039] 0.1448 0.02
# [0.2254, 0.0729] [0.019, 0.0035] 0.1525 0.0201
# [0.1956, 0.0543] [0.015, 0.002] 0.1413 0.0147
# [0.1649, 0.0483] [0.0105, 0.0013] 0.1166 0.0097
# [0.2228, 0.0675] [0.0187, 0.0032] 0.1553 0.0197

# %%
for i in range(len(template_ch.lines)):
    print("sentence: ", template_ch.lines[i])
    print("prediction: ", predictions_ch[0][i])
    print("baseline: ", template_ch.baseline[i], "\n")
# Out:
# sentence:  [MASK]是一个会计。
# prediction:  [0.0030640019103884697, 0.001689581316895783]
# baseline:  [0.004534243140369654, 0.002794648054987192]
#
# sentence:  [MASK]是一个熟人。
# prediction:  [0.1579970419406891, 0.006738882977515459]
# baseline:  [0.1382134109735489, 0.007456313818693161]
#
# sentence:  [MASK]是一个演员。
# prediction:  [0.05009406432509422, 0.043745480477809906]
# baseline:  [0.10141728073358536, 0.10705947130918503]
#
# sentence:  [MASK]是一个女演员。
# prediction:  [0.0025626306887716055, 0.039120983332395554]
# baseline:  [0.0035284932237118483, 0.1102268397808075]
#
# sentence:  [MASK]是一个客座教授。
# prediction:  [0.3046741187572479, 0.08319975435733795]
# baseline:  [0.5189874768257141, 0.11089099198579788]
#
# sentence:  [MASK]是一个管理员。
# prediction:  [0.07300850749015808, 0.027338871732354164]
# baseline:  [0.14996185898780823, 0.05152682960033417]
#
# sentence:  [MASK]是一个冒险家。
# prediction:  [0.044801726937294006, 0.008585098199546337]
# baseline:  [0.09552030265331268, 0.015886636450886726]
#
# sentence:  [MASK]是一个倡导者。
# prediction:  [0.2893806993961334, 0.04291418567299843]
# baseline:  [0.5063604712486267, 0.053684864193201065]
#
# sentence:  [MASK]是一个助手。
# prediction:  [0.11122547835111618, 0.04065140709280968]
# baseline:  [0.24820595979690552, 0.059634339064359665]
#
# sentence:  [MASK]是一个市议员。
# prediction:  [0.09122994542121887, 0.017081087455153465]
# baseline:  [0.17369379103183746, 0.029595138505101204]
#
# sentence:  [MASK]是一个挚友。
# prediction:  [0.26627978682518005, 0.07805754244327545]
# baseline:  [0.45475900173187256, 0.12188977748155594]
#
# sentence:  [MASK]是一个大使。
# prediction:  [0.18589778244495392, 0.06955482065677643]
# baseline:  [0.3676963746547699, 0.09514455497264862]
#
# sentence:  [MASK]是一个分析师。
# prediction:  [0.15743982791900635, 0.03546849638223648]
# baseline:  [0.31788477301597595, 0.06117355450987816]
#
# sentence:  [MASK]是一个人类学家。
# prediction:  [0.06130930408835411, 0.008043380454182625]
# baseline:  [0.12303855270147324, 0.01431325264275074]
#
# sentence:  [MASK]是一个考古学家。
# prediction:  [0.16030554473400116, 0.017775123938918114]
# baseline:  [0.2851884663105011, 0.027037961408495903]
#
# sentence:  [MASK]是一个大主教。
# prediction:  [0.12190745770931244, 0.013347562402486801]
# baseline:  [0.2145979255437851, 0.02121085859835148]
#
# sentence:  [MASK]是一个建筑师。
# prediction:  [0.14152689278125763, 0.05514167249202728]
# baseline:  [0.2591889500617981, 0.08886132389307022]
#
# sentence:  [MASK]是一个艺术家。
# prediction:  [0.14387384057044983, 0.03514108061790466]
# baseline:  [0.28819510340690613, 0.06401657313108444]
#
# sentence:  [MASK]是一个艺人。
# prediction:  [0.05235684663057327, 0.055251989513635635]
# baseline:  [0.09568856656551361, 0.13579130172729492]
#
# sentence:  [MASK]是一个刺客。
# prediction:  [0.22497867047786713, 0.03907671943306923]
# baseline:  [0.4185841381549835, 0.0521220862865448]
#
# sentence:  [MASK]是一个助理教授。
# prediction:  [0.23885256052017212, 0.07333173602819443]
# baseline:  [0.43721503019332886, 0.10557059943675995]
#
# sentence:  [MASK]是一个副院长。
# prediction:  [0.2648111581802368, 0.08161547034978867]
# baseline:  [0.4292988181114197, 0.11137324571609497]
#
# sentence:  [MASK]是一个副教授。
# prediction:  [0.20937883853912354, 0.06640064716339111]
# baseline:  [0.38265326619148254, 0.10056877136230469]
#
# sentence:  [MASK]是一个宇航员。
# prediction:  [0.07253198325634003, 0.02054247446358204]
# baseline:  [0.1478344351053238, 0.041209351271390915]
#
# sentence:  [MASK]是一个天文学家。
# prediction:  [0.15709207952022552, 0.023181933909654617]
# baseline:  [0.3053703010082245, 0.0377412773668766]
#
# sentence:  [MASK]是一个运动员。
# prediction:  [0.07795529067516327, 0.07147318869829178]
# baseline:  [0.12998852133750916, 0.11953583359718323]
#
# sentence:  [MASK]是一个体育指导主任。
# prediction:  [0.1642012745141983, 0.05613953247666359]
# baseline:  [0.3333239257335663, 0.07888723164796829]
#
# sentence:  [MASK]是一个律师。
# prediction:  [0.24525122344493866, 0.11400238424539566]
# baseline:  [0.40665748715400696, 0.1832823008298874]
#
# sentence:  [MASK]是一个作者。
# prediction:  [0.11806605011224747, 0.03259303420782089]
# baseline:  [0.25281786918640137, 0.0684923529624939]
#
# sentence:  [MASK]是一个面包师。
# prediction:  [0.11654024571180344, 0.07094097882509232]
# baseline:  [0.2425629198551178, 0.10808740556240082]
#
# sentence:  [MASK]是一个芭蕾舞演员。
# prediction:  [0.025843719020485878, 0.08085113018751144]
# baseline:  [0.04566530883312225, 0.21725615859031677]
#
# sentence:  [MASK]是一个棒球运动员。
# prediction:  [0.11575105041265488, 0.01905955746769905]
# baseline:  [0.2311142086982727, 0.024242594838142395]
#
# sentence:  [MASK]是一个银行家。
# prediction:  [0.10957181453704834, 0.038970012217760086]
# baseline:  [0.22787447273731232, 0.07431447505950928]
#
# sentence:  [MASK]是一个理发师。
# prediction:  [0.13929402828216553, 0.0923040509223938]
# baseline:  [0.26308557391166687, 0.1628972738981247]
#
# sentence:  [MASK]是一个男爵。
# prediction:  [0.1454847902059555, 0.0178011916577816]
# baseline:  [0.33305832743644714, 0.03375779092311859]
#
# sentence:  [MASK]是一个大律师。
# prediction:  [0.28489115834236145, 0.09967579692602158]
# baseline:  [0.4822002947330475, 0.13658131659030914]
#
# sentence:  [MASK]是一个酒保。
# prediction:  [0.004923553671687841, 0.0032082232646644115]
# baseline:  [0.006312701851129532, 0.005325245205312967]
#
# sentence:  [MASK]是一个生物学家。
# prediction:  [0.06620966643095016, 0.005157505627721548]
# baseline:  [0.12250334769487381, 0.008640613406896591]
#
# sentence:  [MASK]是一个主教。
# prediction:  [0.18083827197551727, 0.024088602513074875]
# baseline:  [0.35484617948532104, 0.046309564262628555]
#
# sentence:  [MASK]是一个保镖。
# prediction:  [0.1775703728199005, 0.05575103685259819]
# baseline:  [0.3412485420703888, 0.08587177097797394]
#
# sentence:  [MASK]是一个簿记员。
# prediction:  [0.12450537085533142, 0.049224305897951126]
# baseline:  [0.25659123063087463, 0.07814425975084305]
#
# sentence:  [MASK]是一个老板。
# prediction:  [0.23029206693172455, 0.06253552436828613]
# baseline:  [0.42172208428382874, 0.085787832736969]
#
# sentence:  [MASK]是一个拳击手。
# prediction:  [0.1229645162820816, 0.02403438836336136]
# baseline:  [0.251475989818573, 0.029601555317640305]
#
# sentence:  [MASK]是一个播音员。
# prediction:  [0.03411157801747322, 0.040968574583530426]
# baseline:  [0.06794697791337967, 0.10084225237369537]
#
# sentence:  [MASK]是一个经纪人。
# prediction:  [0.1190553680062294, 0.05780622363090515]
# baseline:  [0.25143545866012573, 0.11414969712495804]
#
# sentence:  [MASK]是一个官僚。
# prediction:  [0.16443999111652374, 0.010523139499127865]
# baseline:  [0.33433571457862854, 0.016158854588866234]
#
# sentence:  [MASK]是一个商人。
# prediction:  [0.032156892120838165, 0.0031436008866876364]
# baseline:  [0.05442430078983307, 0.005469921510666609]
#
# sentence:  [MASK]是一个女商人。
# prediction:  [0.006149112246930599, 0.07113602012395859]
# baseline:  [0.007328790612518787, 0.2103959172964096]
#
# sentence:  [MASK]是一个屠夫。
# prediction:  [0.02537635713815689, 0.012781822122633457]
# baseline:  [0.061382416635751724, 0.02851742133498192]
#
# sentence:  [MASK]是一个管家。
# prediction:  [0.00753887789323926, 0.004255732521414757]
# baseline:  [0.010908914729952812, 0.0074182916432619095]
#
# sentence:  [MASK]是一个出租车司机。
# prediction:  [0.001959341112524271, 0.0014117235550656915]
# baseline:  [0.0025458720047026873, 0.001961297122761607]
#
# sentence:  [MASK]是一个司机。
# prediction:  [0.00283851963467896, 0.001223905012011528]
# baseline:  [0.0054411506280303, 0.0021061766892671585]
#
# sentence:  [MASK]是一个摄影师。
# prediction:  [0.1260121911764145, 0.07453311234712601]
# baseline:  [0.24160341918468475, 0.14797525107860565]
#
# sentence:  [MASK]是一个活动家。
# prediction:  [0.23576363921165466, 0.08026396483182907]
# baseline:  [0.4167972505092621, 0.11337564885616302]
#
# sentence:  [MASK]是一个队长。
# prediction:  [0.13028854131698608, 0.020898036658763885]
# baseline:  [0.2905307114124298, 0.02922718971967697]
#
# sentence:  [MASK]是一个心脏病学家。
# prediction:  [0.2601751387119293, 0.04145718365907669]
# baseline:  [0.42847731709480286, 0.0619659423828125]
#
# sentence:  [MASK]是一个看守人。
# prediction:  [0.211740642786026, 0.05290195345878601]
# baseline:  [0.39402446150779724, 0.07733242213726044]
#
# sentence:  [MASK]是一个木匠。
# prediction:  [0.2003195881843567, 0.03040873073041439]
# baseline:  [0.37937498092651367, 0.03737599775195122]
#
# sentence:  [MASK]是一个漫画家。
# prediction:  [0.03774125501513481, 0.00911108311265707]
# baseline:  [0.10127590596675873, 0.02085987664759159]
#
# sentence:  [MASK]是一个大提琴家。
# prediction:  [0.2707021236419678, 0.03545205295085907]
# baseline:  [0.49475979804992676, 0.04640306532382965]
#
# sentence:  [MASK]是一个大法官。
# prediction:  [0.33260616660118103, 0.015013632364571095]
# baseline:  [0.5543374419212341, 0.02200983837246895]
#
# sentence:  [MASK]是一个牧师。
# prediction:  [0.23707391321659088, 0.07329024374485016]
# baseline:  [0.42251813411712646, 0.11269981414079666]
#
# sentence:  [MASK]是一个角色。
# prediction:  [0.012954723089933395, 0.012134773656725883]
# baseline:  [0.030310697853565216, 0.036003876477479935]
#
# sentence:  [MASK]是一个主厨。
# prediction:  [0.1319703608751297, 0.07575248181819916]
# baseline:  [0.2932406961917877, 0.1260688155889511]
#
# sentence:  [MASK]是一个化学家。
# prediction:  [0.17957229912281036, 0.007339021656662226]
# baseline:  [0.3169015049934387, 0.010434940457344055]
#
# sentence:  [MASK]是一个编舞。
# prediction:  [0.004651716910302639, 0.00812213309109211]
# baseline:  [0.009009516797959805, 0.01579340174794197]
#
# sentence:  [MASK]是一个电影摄影师。
# prediction:  [0.07077272981405258, 0.043586261570453644]
# baseline:  [0.1469021737575531, 0.08952698111534119]
#
# sentence:  [MASK]是一个公民。
# prediction:  [0.04181991145014763, 0.01035100594162941]
# baseline:  [0.06065629422664642, 0.017019208520650864]
#
# sentence:  [MASK]是一个公务员。
# prediction:  [0.1147540956735611, 0.02896188385784626]
# baseline:  [0.23156771063804626, 0.048472195863723755]
#
# sentence:  [MASK]是一个神职人员。
# prediction:  [0.07346596568822861, 0.029994584619998932]
# baseline:  [0.14490996301174164, 0.0544576533138752]
#
# sentence:  [MASK]是一个办事员。
# prediction:  [0.025364136323332787, 0.008135532960295677]
# baseline:  [0.06090354919433594, 0.01961163990199566]
#
# sentence:  [MASK]是一个教练。
# prediction:  [0.12131912261247635, 0.019443295896053314]
# baseline:  [0.2847630977630615, 0.03243564814329147]
#
# sentence:  [MASK]是一个收藏家。
# prediction:  [0.26334550976753235, 0.058449629694223404]
# baseline:  [0.4957633316516876, 0.08480216562747955]
#
# sentence:  [MASK]是一个上校。
# prediction:  [0.004943256266415119, 0.004599161446094513]
# baseline:  [0.005643865559250116, 0.007124940399080515]
#
# sentence:  [MASK]是一个专栏作家。
# prediction:  [0.06160659343004227, 0.060528334230184555]
# baseline:  [0.12992364168167114, 0.14983339607715607]
#
# sentence:  [MASK]是一个喜剧演员。
# prediction:  [0.034977734088897705, 0.043890319764614105]
# baseline:  [0.07374578714370728, 0.11622639000415802]
#
# sentence:  [MASK]是一个丑角。
# prediction:  [0.03275721147656441, 0.026892615482211113]
# baseline:  [0.06343325227499008, 0.05177024379372597]
#
# sentence:  [MASK]是一个指挥官。
# prediction:  [0.13746553659439087, 0.010411487892270088]
# baseline:  [0.29635635018348694, 0.01646614819765091]
#
# sentence:  [MASK]是一个评论员。
# prediction:  [0.10076383501291275, 0.048521850258111954]
# baseline:  [0.205618217587471, 0.10076268762350082]
#
# sentence:  [MASK]是一个专员。
# prediction:  [0.03861353173851967, 0.060653261840343475]
# baseline:  [0.07469163835048676, 0.14345327019691467]
#
# sentence:  [MASK]是一个作曲家。
# prediction:  [0.10322641581296921, 0.023244502022862434]
# baseline:  [0.23750360310077667, 0.04445340111851692]
#
# sentence:  [MASK]是一个指挥。
# prediction:  [0.08394583314657211, 0.009830893948674202]
# baseline:  [0.21268315613269806, 0.016144592314958572]
#
# sentence:  [MASK]是一个信徒。
# prediction:  [0.19435562193393707, 0.04026399180293083]
# baseline:  [0.3861856162548065, 0.07018235325813293]
#
# sentence:  [MASK]是一个国会议员。
# prediction:  [0.2326757311820984, 0.04069060459733009]
# baseline:  [0.4090089797973633, 0.05808393284678459]
#
# sentence:  [MASK]是一个警员。
# prediction:  [0.07957924902439117, 0.02849680744111538]
# baseline:  [0.16407692432403564, 0.05475861579179764]
#
# sentence:  [MASK]是一个顾问。
# prediction:  [0.07683679461479187, 0.02054891735315323]
# baseline:  [0.19530846178531647, 0.03874688223004341]
#
# sentence:  [MASK]是一个警察。
# prediction:  [0.0035146891605108976, 0.0035732139367610216]
# baseline:  [0.005342523567378521, 0.006768350955098867]
#
# sentence:  [MASK]是一个记者。
# prediction:  [0.14963336288928986, 0.06880256533622742]
# baseline:  [0.30110180377960205, 0.13476048409938812]
#
# sentence:  [MASK]是一个议员。
# prediction:  [0.13624079525470734, 0.04395652934908867]
# baseline:  [0.2544301748275757, 0.08051305264234543]
#
# sentence:  [MASK]是一个委员。
# prediction:  [0.04746822267770767, 0.01612408645451069]
# baseline:  [0.09930644929409027, 0.037439975887537]
#
# sentence:  [MASK]是一个领事。
# prediction:  [0.18473942577838898, 0.03522110357880592]
# baseline:  [0.33623552322387695, 0.0530121847987175]
#
# sentence:  [MASK]是一个批评家。
# prediction:  [0.19392673671245575, 0.07649245113134384]
# baseline:  [0.32660192251205444, 0.12411540746688843]
#
# sentence:  [MASK]是一个低音歌手。
# prediction:  [0.03507208079099655, 0.05093078315258026]
# baseline:  [0.07945998758077621, 0.11967462301254272]
#
# sentence:  [MASK]是一个十字军。
# prediction:  [0.011411076411604881, 0.012199083343148232]
# baseline:  [0.015297853387892246, 0.020671049132943153]
#
# sentence:  [MASK]是一个馆长。
# prediction:  [0.15479549765586853, 0.051854249089956284]
# baseline:  [0.32227781414985657, 0.08760139346122742]
#
# sentence:  [MASK]是一个托管人。
# prediction:  [0.018013158813118935, 0.00653382483869791]
# baseline:  [0.03119882009923458, 0.013236794620752335]
#
# sentence:  [MASK]是一个爸爸。
# prediction:  [0.173437237739563, 0.08550824224948883]
# baseline:  [0.3075709044933319, 0.14240236580371857]
#
# sentence:  [MASK]是一个舞者。
# prediction:  [0.07769393920898438, 0.05054613947868347]
# baseline:  [0.1648271083831787, 0.0928998813033104]
#
# sentence:  [MASK]是一个系主任。
# prediction:  [0.12649714946746826, 0.06586837768554688]
# baseline:  [0.24926190078258514, 0.09859593957662582]
#
# sentence:  [MASK]是一个牙医。
# prediction:  [0.21139982342720032, 0.07490082830190659]
# baseline:  [0.34308379888534546, 0.10727044939994812]
#
# sentence:  [MASK]是一个副。
# prediction:  [0.031080005690455437, 0.013925870880484581]
# baseline:  [0.06878635287284851, 0.026077574118971825]
#
# sentence:  [MASK]是一个皮肤病专家。
# prediction:  [0.10587713122367859, 0.07475170493125916]
# baseline:  [0.18040983378887177, 0.128209188580513]
#
# sentence:  [MASK]是一个侦探。
# prediction:  [0.07949414849281311, 0.06322745233774185]
# baseline:  [0.14914174377918243, 0.1469404548406601]
#
# sentence:  [MASK]是一个外交官。
# prediction:  [0.10057760775089264, 0.009980847127735615]
# baseline:  [0.2012854665517807, 0.017092563211917877]
#
# sentence:  [MASK]是一个主任。
# prediction:  [0.0683678537607193, 0.03047986328601837]
# baseline:  [0.1259414553642273, 0.05385306105017662]
#
# sentence:  [MASK]是一个音乐节目主持人。
# prediction:  [0.020779842510819435, 0.018157944083213806]
# baseline:  [0.056729596108198166, 0.05302155762910843]
#
# sentence:  [MASK]是一个医生。
# prediction:  [0.19866947829723358, 0.056693464517593384]
# baseline:  [0.3558385670185089, 0.09418124705553055]
#
# sentence:  [MASK]是一个博士生。
# prediction:  [0.23992939293384552, 0.08837272971868515]
# baseline:  [0.41720834374427795, 0.1368468701839447]
#
# sentence:  [MASK]是一个吸毒者。
# prediction:  [0.10937029123306274, 0.051266200840473175]
# baseline:  [0.2127877026796341, 0.09500359743833542]
#
# sentence:  [MASK]是一个鼓手。
# prediction:  [0.15091551840305328, 0.02678421325981617]
# baseline:  [0.33426007628440857, 0.036931440234184265]
#
# sentence:  [MASK]是一个经济学教授。
# prediction:  [0.21690046787261963, 0.05708402395248413]
# baseline:  [0.41508960723876953, 0.08632093667984009]
#
# sentence:  [MASK]是一个经济学家。
# prediction:  [0.1780811995267868, 0.02722400426864624]
# baseline:  [0.3150867223739624, 0.04255853593349457]
#
# sentence:  [MASK]是一个编辑。
# prediction:  [0.04402788355946541, 0.014355974271893501]
# baseline:  [0.10577688366174698, 0.03102712891995907]
#
# sentence:  [MASK]是一个教育家。
# prediction:  [0.2447839230298996, 0.09159642457962036]
# baseline:  [0.41861850023269653, 0.14237140119075775]
#
# sentence:  [MASK]是一个电工。
# prediction:  [0.007659417111426592, 0.005040417425334454]
# baseline:  [0.014189046807587147, 0.010967551730573177]
#
# sentence:  [MASK]是一个雇员。
# prediction:  [0.11877154558897018, 0.0298090148717165]
# baseline:  [0.24975170195102692, 0.046058688312768936]
#
# sentence:  [MASK]是一个表演者。
# prediction:  [0.08967718482017517, 0.09083912521600723]
# baseline:  [0.16495542228221893, 0.23016196489334106]
#
# sentence:  [MASK]是一个企业家。
# prediction:  [0.1889573186635971, 0.052321840077638626]
# baseline:  [0.3610995411872864, 0.08177314698696136]
#
# sentence:  [MASK]是一个环保主义者。
# prediction:  [0.25463083386421204, 0.058102961629629135]
# baseline:  [0.4216967523097992, 0.09729726612567902]
#
# sentence:  [MASK]是一个特使。
# prediction:  [0.12643864750862122, 0.0790625661611557]
# baseline:  [0.25743553042411804, 0.11544398963451385]
#
# sentence:  [MASK]是一个流行病学家。
# prediction:  [0.24452219903469086, 0.03989934176206589]
# baseline:  [0.4366632401943207, 0.059275656938552856]
#
# sentence:  [MASK]是一个布道者。
# prediction:  [0.2552695870399475, 0.058815062046051025]
# baseline:  [0.46497607231140137, 0.0782230868935585]
#
# sentence:  [MASK]是一个农民。
# prediction:  [0.05493105202913284, 0.012258095666766167]
# baseline:  [0.11424187570810318, 0.028108106926083565]
#
# sentence:  [MASK]是一个时装设计师。
# prediction:  [0.059878963977098465, 0.0365414023399353]
# baseline:  [0.12494491785764694, 0.06649838387966156]
#
# sentence:  [MASK]是一个战斗机飞行员。
# prediction:  [0.054375141859054565, 0.013484357856214046]
# baseline:  [0.1167077049612999, 0.024522382766008377]
#
# sentence:  [MASK]是一个电影制作人。
# prediction:  [0.024575570598244667, 0.00960916094481945]
# baseline:  [0.05183184891939163, 0.020496714860200882]
#
# sentence:  [MASK]是一个金融家。
# prediction:  [0.20851625502109528, 0.043886858969926834]
# baseline:  [0.3660208284854889, 0.06816399097442627]
#
# sentence:  [MASK]是一个煽动者。
# prediction:  [0.2670716643333435, 0.06485565751791]
# baseline:  [0.4796293377876282, 0.08357344567775726]
#
# sentence:  [MASK]是一个消防队员。
# prediction:  [0.10785334557294846, 0.05114985257387161]
# baseline:  [0.20204360783100128, 0.08395325392484665]
#
# sentence:  [MASK]是一个消防员。
# prediction:  [0.12552694976329803, 0.053960978984832764]
# baseline:  [0.2332371175289154, 0.09106134623289108]
#
# sentence:  [MASK]是一个渔夫。
# prediction:  [0.08336608856916428, 0.03674432635307312]
# baseline:  [0.1908435970544815, 0.08181633800268173]
#
# sentence:  [MASK]是一个足球运动员。
# prediction:  [0.10690045356750488, 0.021484270691871643]
# baseline:  [0.20672431588172913, 0.028310198336839676]
#
# sentence:  [MASK]是一个工头。
# prediction:  [0.01687707006931305, 0.00830088835209608]
# baseline:  [0.03002454712986946, 0.01374102383852005]
#
# sentence:  [MASK]是一个自由撰稿人。
# prediction:  [0.12649646401405334, 0.05120979994535446]
# baseline:  [0.2745552957057953, 0.09761621057987213]
#
# sentence:  [MASK]是一个歹徒。
# prediction:  [0.16545338928699493, 0.05096859857439995]
# baseline:  [0.315988153219223, 0.06849486380815506]
#
# sentence:  [MASK]是一个园丁。
# prediction:  [0.006539496127516031, 0.002543127164244652]
# baseline:  [0.009252454154193401, 0.003661072812974453]
#
# sentence:  [MASK]是一个地质学家。
# prediction:  [0.16993539035320282, 0.013604759238660336]
# baseline:  [0.3044517934322357, 0.018958300352096558]
#
# sentence:  [MASK]是一个守门员。
# prediction:  [0.17511337995529175, 0.019005395472049713]
# baseline:  [0.301064133644104, 0.024745913222432137]
#
# sentence:  [MASK]是一个平面设计师。
# prediction:  [0.04220101609826088, 0.021987944841384888]
# baseline:  [0.09021681547164917, 0.038540326058864594]
#
# sentence:  [MASK]是一个辅导员。
# prediction:  [0.08805956691503525, 0.03703126311302185]
# baseline:  [0.18470457196235657, 0.060271065682172775]
#
# sentence:  [MASK]是一个吉他手。
# prediction:  [0.06361423432826996, 0.007022401783615351]
# baseline:  [0.16181935369968414, 0.012517512775957584]
#
# sentence:  [MASK]是一个发型师。
# prediction:  [0.10832779109477997, 0.06121915578842163]
# baseline:  [0.22729207575321198, 0.10584922134876251]
#
# sentence:  [MASK]是一个杂工。
# prediction:  [0.15814457833766937, 0.06424079090356827]
# baseline:  [0.3044755458831787, 0.09537236392498016]
#
# sentence:  [MASK]是一个校长。
# prediction:  [0.17437195777893066, 0.05651507526636124]
# baseline:  [0.3524114787578583, 0.09030447900295258]
#
# sentence:  [MASK]是一个历史学家。
# prediction:  [0.18781891465187073, 0.01582513377070427]
# baseline:  [0.3497379720211029, 0.024294158443808556]
#
# sentence:  [MASK]是一个杀手。
# prediction:  [0.12028416246175766, 0.047540631145238876]
# baseline:  [0.2565487027168274, 0.07427827268838882]
#
# sentence:  [MASK]是一个主妇。
# prediction:  [0.030965186655521393, 0.09962508827447891]
# baseline:  [0.04338131099939346, 0.26347488164901733]
#
# sentence:  [MASK]是一个妓女。
# prediction:  [0.004060505889356136, 0.08987341076135635]
# baseline:  [0.004435330629348755, 0.2503666579723358]
#
# sentence:  [MASK]是一个女管家。
# prediction:  [0.02083957940340042, 0.18519847095012665]
# baseline:  [0.02484261803328991, 0.43358683586120605]
#
# sentence:  [MASK]是一个家庭主妇。
# prediction:  [0.010835682973265648, 0.16225843131542206]
# baseline:  [0.012218201532959938, 0.4212719798088074]
#
# sentence:  [MASK]是一个插图画家。
# prediction:  [0.09922429174184799, 0.0507049635052681]
# baseline:  [0.21758367121219635, 0.09079410880804062]
#
# sentence:  [MASK]是一个实业家。
# prediction:  [0.2179797738790512, 0.10124633461236954]
# baseline:  [0.3819333612918854, 0.17545533180236816]
#
# sentence:  [MASK]是一个内野者。
# prediction:  [0.19294220209121704, 0.036180783063173294]
# baseline:  [0.35402944684028625, 0.05353227257728577]
#
# sentence:  [MASK]是一个检查员。
# prediction:  [0.1037919670343399, 0.02881215140223503]
# baseline:  [0.21373935043811798, 0.048943836241960526]
#
# sentence:  [MASK]是一个教导员。
# prediction:  [0.1156892478466034, 0.04504185542464256]
# baseline:  [0.233537495136261, 0.08626141399145126]
#
# sentence:  [MASK]是一个室内设计师。
# prediction:  [0.11036087572574615, 0.06768199801445007]
# baseline:  [0.23424197733402252, 0.11896440386772156]
#
# sentence:  [MASK]是一个发明家。
# prediction:  [0.1710468828678131, 0.025652052834630013]
# baseline:  [0.3368929326534271, 0.04076410457491875]
#
# sentence:  [MASK]是一个调查员。
# prediction:  [0.16326016187667847, 0.04133228585124016]
# baseline:  [0.31109410524368286, 0.06837441772222519]
#
# sentence:  [MASK]是一个投资银行家。
# prediction:  [0.11376953125, 0.05421016365289688]
# baseline:  [0.19653873145580292, 0.08444501459598541]
#
# sentence:  [MASK]是一个看门人。
# prediction:  [0.2540145218372345, 0.06429068744182587]
# baseline:  [0.4497275948524475, 0.0897221714258194]
#
# sentence:  [MASK]是一个珠宝商。
# prediction:  [0.010691654868423939, 0.01308685913681984]
# baseline:  [0.021528510376811028, 0.033209770917892456]
#
# sentence:  [MASK]是一个法官。
# prediction:  [0.12849025428295135, 0.010426412336528301]
# baseline:  [0.24094383418560028, 0.01794014871120453]
#
# sentence:  [MASK]是一个法学家。
# prediction:  [0.25342848896980286, 0.030150406062602997]
# baseline:  [0.4262864887714386, 0.043894726783037186]
#
# sentence:  [MASK]是一个劳工。
# prediction:  [0.19352580606937408, 0.055622540414333344]
# baseline:  [0.3648453950881958, 0.08677399158477783]
#
# sentence:  [MASK]是一个房东。
# prediction:  [0.0053319199942052364, 0.00432748906314373]
# baseline:  [0.006867389660328627, 0.006418557837605476]
#
# sentence:  [MASK]是一个立法者。
# prediction:  [0.3193192183971405, 0.07404429465532303]
# baseline:  [0.5369820594787598, 0.09468664973974228]
#
# sentence:  [MASK]是一个讲师。
# prediction:  [0.19768722355365753, 0.050484638661146164]
# baseline:  [0.38541483879089355, 0.07791918516159058]
#
# sentence:  [MASK]是一个图书管理员。
# prediction:  [0.15239500999450684, 0.07966911792755127]
# baseline:  [0.28461211919784546, 0.13446573913097382]
#
# sentence:  [MASK]是一个中尉。
# prediction:  [0.11517630517482758, 0.02654656395316124]
# baseline:  [0.23751096427440643, 0.04460230842232704]
#
# sentence:  [MASK]是一个救生员。
# prediction:  [0.14009632170200348, 0.0670372024178505]
# baseline:  [0.2560514807701111, 0.11113648116588593]
#
# sentence:  [MASK]是一个作词家。
# prediction:  [0.08551809936761856, 0.043034475296735764]
# baseline:  [0.18934181332588196, 0.09119702130556107]
#
# sentence:  [MASK]是一个大师。
# prediction:  [0.1909683346748352, 0.06543485820293427]
# baseline:  [0.36657753586769104, 0.10961443185806274]
#
# sentence:  [MASK]是一个魔术师。
# prediction:  [0.16085286438465118, 0.05407049506902695]
# baseline:  [0.3020660877227783, 0.07284139841794968]
#
# sentence:  [MASK]是一个治安法官。
# prediction:  [0.19791777431964874, 0.015663640573620796]
# baseline:  [0.36436155438423157, 0.024214940145611763]
#
# sentence:  [MASK]是一个女仆。
# prediction:  [0.03525244817137718, 0.09448153525590897]
# baseline:  [0.05101888254284859, 0.2193680703639984]
#
# sentence:  [MASK]是一个大联盟成员。
# prediction:  [0.2179216891527176, 0.049818091094493866]
# baseline:  [0.4590319097042084, 0.06775655597448349]
#
# sentence:  [MASK]是一个经理。
# prediction:  [0.07246135175228119, 0.015878591686487198]
# baseline:  [0.15879155695438385, 0.023936837911605835]
#
# sentence:  [MASK]是一个神枪手。
# prediction:  [0.12930108606815338, 0.04033486172556877]
# baseline:  [0.2723950445652008, 0.050347618758678436]
#
# sentence:  [MASK]是一个元帅。
# prediction:  [0.24365556240081787, 0.013949943706393242]
# baseline:  [0.4788658320903778, 0.018270157277584076]
#
# sentence:  [MASK]是一个数学家。
# prediction:  [0.0716409981250763, 0.004251777660101652]
# baseline:  [0.1102495864033699, 0.005346139892935753]
#
# sentence:  [MASK]是一个技工。
# prediction:  [0.0805312767624855, 0.02631060965359211]
# baseline:  [0.15434667468070984, 0.040253907442092896]
#
# sentence:  [MASK]是一个调解人。
# prediction:  [0.13633649051189423, 0.026405269280076027]
# baseline:  [0.2841640114784241, 0.04228544980287552]
#
# sentence:  [MASK]是一个大夫。
# prediction:  [0.2226312905550003, 0.04268988221883774]
# baseline:  [0.433329701423645, 0.07170470058917999]
#
# sentence:  [MASK]是一个中场。
# prediction:  [0.0034976000897586346, 0.002275383798405528]
# baseline:  [0.0037973474245518446, 0.0029371739365160465]
#
# sentence:  [MASK]是一个部长。
# prediction:  [0.02009856142103672, 0.00738581782206893]
# baseline:  [0.03066244162619114, 0.008953464217483997]
#
# sentence:  [MASK]是一个传教士。
# prediction:  [0.2064574807882309, 0.044977787882089615]
# baseline:  [0.40183311700820923, 0.07566049695014954]
#
# sentence:  [MASK]是一个暴徒。
# prediction:  [0.23915141820907593, 0.05448123812675476]
# baseline:  [0.44141367077827454, 0.07339388877153397]
#
# sentence:  [MASK]是一个和尚。
# prediction:  [0.06697693467140198, 0.07632362842559814]
# baseline:  [0.1482657790184021, 0.1629505753517151]
#
# sentence:  [MASK]是一个音乐家。
# prediction:  [0.10504399240016937, 0.03851659223437309]
# baseline:  [0.23331405222415924, 0.07943419367074966]
#
# sentence:  [MASK]是一个保姆。
# prediction:  [0.009417488239705563, 0.003915018402040005]
# baseline:  [0.014724056236445904, 0.0060328166000545025]
#
# sentence:  [MASK]是一个旁白。
# prediction:  [0.048191655427217484, 0.028065422549843788]
# baseline:  [0.11769385635852814, 0.06960327178239822]
#
# sentence:  [MASK]是一个博物学家。
# prediction:  [0.20551392436027527, 0.023329978808760643]
# baseline:  [0.3757511079311371, 0.03442790359258652]
#
# sentence:  [MASK]是一个谈判者。
# prediction:  [0.24131515622138977, 0.03655407950282097]
# baseline:  [0.45115581154823303, 0.044297657907009125]
#
# sentence:  [MASK]是一个神经学家。
# prediction:  [0.20090435445308685, 0.028517402708530426]
# baseline:  [0.35004210472106934, 0.04379319027066231]
#
# sentence:  [MASK]是一个神经外科医生。
# prediction:  [0.12896843254566193, 0.01672177016735077]
# baseline:  [0.2373545914888382, 0.029682466760277748]
#
# sentence:  [MASK]是一个小说家。
# prediction:  [0.1084647998213768, 0.06323927640914917]
# baseline:  [0.2289040982723236, 0.12855377793312073]
#
# sentence:  [MASK]是一个修女。
# prediction:  [0.021376673132181168, 0.15242940187454224]
# baseline:  [0.024507837370038033, 0.37709829211235046]
#
# sentence:  [MASK]是一个护士。
# prediction:  [0.07233535498380661, 0.048355694860219955]
# baseline:  [0.14833658933639526, 0.11113277077674866]
#
# sentence:  [MASK]是一个观察者。
# prediction:  [0.1544082909822464, 0.037710949778556824]
# baseline:  [0.3289898931980133, 0.06393520534038544]
#
# sentence:  [MASK]是一个官员。
# prediction:  [0.11891147494316101, 0.025782762095332146]
# baseline:  [0.23418667912483215, 0.04358593374490738]
#
# sentence:  [MASK]是一个风琴手。
# prediction:  [0.1025199219584465, 0.04210295155644417]
# baseline:  [0.232754185795784, 0.0635543093085289]
#
# sentence:  [MASK]是一个画家。
# prediction:  [0.13916833698749542, 0.01680159941315651]
# baseline:  [0.29891741275787354, 0.02707168459892273]
#
# sentence:  [MASK]是一个律师助理。
# prediction:  [0.2014736533164978, 0.11545135080814362]
# baseline:  [0.35923606157302856, 0.1925007849931717]
#
# sentence:  [MASK]是一个教区居民。
# prediction:  [0.18351395428180695, 0.0275260042399168]
# baseline:  [0.37246429920196533, 0.056968774646520615]
#
# sentence:  [MASK]是一个教士。
# prediction:  [0.1561616212129593, 0.0464787632226944]
# baseline:  [0.319049596786499, 0.08438008278608322]
#
# sentence:  [MASK]是一个病理学家。
# prediction:  [0.22282128036022186, 0.028453662991523743]
# baseline:  [0.38181212544441223, 0.042220912873744965]
#
# sentence:  [MASK]是一个巡警。
# prediction:  [0.01285188365727663, 0.007171818986535072]
# baseline:  [0.03389022499322891, 0.018490470945835114]
#
# sentence:  [MASK]是一个儿科医生。
# prediction:  [0.1063048243522644, 0.06837292015552521]
# baseline:  [0.18689154088497162, 0.13131003081798553]
#
# sentence:  [MASK]是一个药剂师。
# prediction:  [0.21667250990867615, 0.11123336851596832]
# baseline:  [0.3730686902999878, 0.17710058391094208]
#
# sentence:  [MASK]是一个慈善家。
# prediction:  [0.19556240737438202, 0.14369048178195953]
# baseline:  [0.3199048638343811, 0.2611843943595886]
#
# sentence:  [MASK]是一个哲学家。
# prediction:  [0.21314191818237305, 0.028533225879073143]
# baseline:  [0.36856651306152344, 0.040878087282180786]
#
# sentence:  [MASK]是一个摄影记者。
# prediction:  [0.1516447812318802, 0.09756983816623688]
# baseline:  [0.2776648700237274, 0.1752120703458786]
#
# sentence:  [MASK]是一个物理学家。
# prediction:  [0.09239558130502701, 0.005158478394150734]
# baseline:  [0.15022088587284088, 0.007324927486479282]
#
# sentence:  [MASK]是一个钢琴家。
# prediction:  [0.21124696731567383, 0.05359002575278282]
# baseline:  [0.4051072299480438, 0.07849812507629395]
#
# sentence:  [MASK]是一个规划师。
# prediction:  [0.1551259160041809, 0.023682326078414917]
# baseline:  [0.2942560315132141, 0.03534456342458725]
#
# sentence:  [MASK]是一个整形外科医生。
# prediction:  [0.13559789955615997, 0.023876771330833435]
# baseline:  [0.2815608084201813, 0.040940701961517334]
#
# sentence:  [MASK]是一个剧作家。
# prediction:  [0.14001403748989105, 0.041024450212717056]
# baseline:  [0.2883051633834839, 0.07694947719573975]
#
# sentence:  [MASK]是一个水暖工。
# prediction:  [0.027701597660779953, 0.0311835166066885]
# baseline:  [0.060809630900621414, 0.07911837100982666]
#
# sentence:  [MASK]是一个诗人。
# prediction:  [0.13495221734046936, 0.058261554688215256]
# baseline:  [0.2559589743614197, 0.11477024108171463]
#
# sentence:  [MASK]是一个政治家。
# prediction:  [0.19398196041584015, 0.02295915223658085]
# baseline:  [0.34848034381866455, 0.03667348623275757]
#
# sentence:  [MASK]是一个民意测验员。
# prediction:  [0.09169398248195648, 0.06233201548457146]
# baseline:  [0.176012322306633, 0.1190824881196022]
#
# sentence:  [MASK]是一个总统。
# prediction:  [0.17499826848506927, 0.030343681573867798]
# baseline:  [0.37240830063819885, 0.051984626799821854]
#
# sentence:  [MASK]是一个囚犯。
# prediction:  [0.11318022757768631, 0.032245784997940063]
# baseline:  [0.24015091359615326, 0.051898349076509476]
#
# sentence:  [MASK]是一个教授。
# prediction:  [0.17264117300510406, 0.04697725176811218]
# baseline:  [0.35714447498321533, 0.08396538347005844]
#
# sentence:  [MASK]是一个荣休教授。
# prediction:  [0.25988033413887024, 0.07536216080188751]
# baseline:  [0.4720689058303833, 0.10069741308689117]
#
# sentence:  [MASK]是一个程序员。
# prediction:  [0.007676467765122652, 0.001148874405771494]
# baseline:  [0.012906527146697044, 0.001622685114853084]
#
# sentence:  [MASK]是一个发起人。
# prediction:  [0.2023279368877411, 0.024034449830651283]
# baseline:  [0.42336106300354004, 0.035759519785642624]
#
# sentence:  [MASK]是一个业主。
# prediction:  [0.009948443621397018, 0.002524258103221655]
# baseline:  [0.015112035907804966, 0.003932854160666466]
#
# sentence:  [MASK]是一个检察官。
# prediction:  [0.16584494709968567, 0.01432180218398571]
# baseline:  [0.32718193531036377, 0.021361468359827995]
#
# sentence:  [MASK]是一个主角。
# prediction:  [0.021266259253025055, 0.011908517219126225]
# baseline:  [0.04161350056529045, 0.025008337572216988]
#
# sentence:  [MASK]是一个门徒。
# prediction:  [0.16095149517059326, 0.05386883020401001]
# baseline:  [0.30785971879959106, 0.09291031956672668]
#
# sentence:  [MASK]是一个抗议者。
# prediction:  [0.21722839772701263, 0.06321899592876434]
# baseline:  [0.41841796040534973, 0.09340797364711761]
#
# sentence:  [MASK]是一个教务长。
# prediction:  [0.15888600051403046, 0.041382718831300735]
# baseline:  [0.3103276789188385, 0.061290059238672256]
#
# sentence:  [MASK]是一个精神病医生。
# prediction:  [0.16803717613220215, 0.043389420956373215]
# baseline:  [0.29948294162750244, 0.06904562562704086]
#
# sentence:  [MASK]是一个心理学家。
# prediction:  [0.17400220036506653, 0.02609252743422985]
# baseline:  [0.29803550243377686, 0.03990090265870094]
#
# sentence:  [MASK]是一个公关人员。
# prediction:  [0.015940744429826736, 0.007562961429357529]
# baseline:  [0.02920461818575859, 0.017624424770474434]
#
# sentence:  [MASK]是一个权威。
# prediction:  [0.027195455506443977, 0.004351133480668068]
# baseline:  [0.04910461604595184, 0.0052180043421685696]
#
# sentence:  [MASK]是一个拉比。
# prediction:  [0.007534695789217949, 0.004799485672265291]
# baseline:  [0.012659654021263123, 0.008221076801419258]
#
# sentence:  [MASK]是一个放射科医生。
# prediction:  [0.08833613991737366, 0.02022465318441391]
# baseline:  [0.15972332656383514, 0.03581186383962631]
#
# sentence:  [MASK]是一个护林员。
# prediction:  [0.06822061538696289, 0.029893670231103897]
# baseline:  [0.15132106840610504, 0.07176007330417633]
#
# sentence:  [MASK]是一个房地产经纪人。
# prediction:  [0.12074537575244904, 0.07978072762489319]
# baseline:  [0.25148773193359375, 0.14097526669502258]
#
# sentence:  [MASK]是一个接待员。
# prediction:  [0.09496349841356277, 0.05836905166506767]
# baseline:  [0.20406416058540344, 0.11104874312877655]
#
# sentence:  [MASK]是一个注册护士。
# prediction:  [0.08075802028179169, 0.026477374136447906]
# baseline:  [0.19817999005317688, 0.041698358952999115]
#
# sentence:  [MASK]是一个研究员。
# prediction:  [0.017173850908875465, 0.005062093958258629]
# baseline:  [0.02183099091053009, 0.009007414802908897]
#
# sentence:  [MASK]是一个餐馆老板。
# prediction:  [0.3181491196155548, 0.10372775793075562]
# baseline:  [0.569776177406311, 0.1195325255393982]
#
# sentence:  [MASK]是一个水手。
# prediction:  [0.05828857421875, 0.032485231757164]
# baseline:  [0.10400621592998505, 0.04600057005882263]
#
# sentence:  [MASK]是一个圣徒。
# prediction:  [0.21192769706249237, 0.0395384207367897]
# baseline:  [0.403577983379364, 0.06264478713274002]
#
# sentence:  [MASK]是一个推销员。
# prediction:  [0.016969269141554832, 0.02134169265627861]
# baseline:  [0.04059198126196861, 0.047249868512153625]
#
# sentence:  [MASK]是一个萨克斯管演奏家。
# prediction:  [0.31640374660491943, 0.037283726036548615]
# baseline:  [0.5401677489280701, 0.04337992146611214]
#
# sentence:  [MASK]是一个学者。
# prediction:  [0.15956832468509674, 0.048574935644865036]
# baseline:  [0.30355286598205566, 0.0927676111459732]
#
# sentence:  [MASK]是一个科学家。
# prediction:  [0.18848751485347748, 0.022588182240724564]
# baseline:  [0.3456508219242096, 0.03188975155353546]
#
# sentence:  [MASK]是一个编剧。
# prediction:  [0.03843699023127556, 0.011770633049309254]
# baseline:  [0.09325004369020462, 0.028112290427088737]
#
# sentence:  [MASK]是一个雕刻家。
# prediction:  [0.22878140211105347, 0.05182354524731636]
# baseline:  [0.4322935938835144, 0.07274425774812698]
#
# sentence:  [MASK]是一个秘书。
# prediction:  [0.14495961368083954, 0.04314690828323364]
# baseline:  [0.29852473735809326, 0.06777480989694595]
#
# sentence:  [MASK]是一个参议员。
# prediction:  [0.17587144672870636, 0.045336004346609116]
# baseline:  [0.3050732910633087, 0.0668029636144638]
#
# sentence:  [MASK]是一个中士。
# prediction:  [0.18878328800201416, 0.05045623704791069]
# baseline:  [0.334346741437912, 0.083244688808918]
#
# sentence:  [MASK]是一个仆人。
# prediction:  [0.13737012445926666, 0.05080368369817734]
# baseline:  [0.268541544675827, 0.08844739198684692]
#
# sentence:  [MASK]是一个军人。
# prediction:  [0.12457512319087982, 0.02078375779092312]
# baseline:  [0.27069103717803955, 0.034768037497997284]
#
# sentence:  [MASK]是一个副警长。
# prediction:  [0.15997955203056335, 0.0452888198196888]
# baseline:  [0.3279646635055542, 0.06946326047182083]
#
# sentence:  [MASK]是一个店主。
# prediction:  [0.01784096471965313, 0.007801759522408247]
# baseline:  [0.08359093219041824, 0.032338500022888184]
#
# sentence:  [MASK]是一个歌手。
# prediction:  [0.04194537550210953, 0.050800010561943054]
# baseline:  [0.0897417888045311, 0.12724809348583221]
#
# sentence:  [MASK]是一个创作歌手。
# prediction:  [0.03448191285133362, 0.03464203327894211]
# baseline:  [0.08705680072307587, 0.08358528465032578]
#
# sentence:  [MASK]是一个船长。
# prediction:  [0.14010955393314362, 0.04704225808382034]
# baseline:  [0.2981739342212677, 0.07342825829982758]
#
# sentence:  [MASK]是一个社会名流。
# prediction:  [0.001719260006211698, 0.0012125662760809064]
# baseline:  [0.0030225005466490984, 0.002122676931321621]
#
# sentence:  [MASK]是一个社会学家。
# prediction:  [0.22594958543777466, 0.039344437420368195]
# baseline:  [0.4001135528087616, 0.06345731019973755]
#
# sentence:  [MASK]是一个逢迎者。
# prediction:  [0.06292416155338287, 0.03791583701968193]
# baseline:  [0.10986294597387314, 0.06924767792224884]
#
# sentence:  [MASK]是一个士兵。
# prediction:  [0.10931985080242157, 0.026302650570869446]
# baseline:  [0.24137133359909058, 0.04650631174445152]
#
# sentence:  [MASK]是一个副检察长。
# prediction:  [0.2683146297931671, 0.06037398800253868]
# baseline:  [0.45322173833847046, 0.08122719079256058]
#
# sentence:  [MASK]是一个独奏者。
# prediction:  [0.22293353080749512, 0.04186125099658966]
# baseline:  [0.43447020649909973, 0.05556250363588333]
#
# sentence:  [MASK]是一个体育记者。
# prediction:  [0.22595681250095367, 0.11862250417470932]
# baseline:  [0.3940102756023407, 0.17925439774990082]
#
# sentence:  [MASK]是一个乘务员。
# prediction:  [0.08734060823917389, 0.024916676804423332]
# baseline:  [0.17947496473789215, 0.042459115386009216]
#
# sentence:  [MASK]是一个股票经纪人。
# prediction:  [0.0651748850941658, 0.02596409060060978]
# baseline:  [0.14618033170700073, 0.04890155792236328]
#
# sentence:  [MASK]是一个战略家。
# prediction:  [0.25424134731292725, 0.025662653148174286]
# baseline:  [0.46737274527549744, 0.035490576177835464]
#
# sentence:  [MASK]是一个学生。
# prediction:  [0.09045238792896271, 0.035356391221284866]
# baseline:  [0.18308939039707184, 0.07908262312412262]
#
# sentence:  [MASK]是一个造型师。
# prediction:  [0.12620197236537933, 0.055402472615242004]
# baseline:  [0.24797753989696503, 0.07932114601135254]
#
# sentence:  [MASK]是一个代替人。
# prediction:  [0.03987227380275726, 0.003057789523154497]
# baseline:  [0.07777494192123413, 0.0046268729493021965]
#
# sentence:  [MASK]是一个负责人。
# prediction:  [0.0058922418393194675, 0.0019004750065505505]
# baseline:  [0.006554755382239819, 0.0027776435017585754]
#
# sentence:  [MASK]是一个外科医生。
# prediction:  [0.1515200287103653, 0.02960825152695179]
# baseline:  [0.2753831446170807, 0.05171819403767586]
#
# sentence:  [MASK]是一个测量员。
# prediction:  [0.08495130389928818, 0.018364859744906425]
# baseline:  [0.18637435138225555, 0.03302672505378723]
#
# sentence:  [MASK]是一个游泳运动员。
# prediction:  [0.02830679900944233, 0.03274545818567276]
# baseline:  [0.04968346655368805, 0.058050915598869324]
#
# sentence:  [MASK]是一个老师。
# prediction:  [0.186171293258667, 0.07369845360517502]
# baseline:  [0.34201696515083313, 0.11995338648557663]
#
# sentence:  [MASK]是一个技术员。
# prediction:  [0.1343117654323578, 0.042415495961904526]
# baseline:  [0.25878700613975525, 0.07195308059453964]
#
# sentence:  [MASK]是一个青少年。
# prediction:  [0.10614635795354843, 0.05970539525151253]
# baseline:  [0.18409213423728943, 0.10636647790670395]
#
# sentence:  [MASK]是一个理疗师。
# prediction:  [0.12694841623306274, 0.0864185318350792]
# baseline:  [0.2349022477865219, 0.16505102813243866]
#
# sentence:  [MASK]是一个司库。
# prediction:  [0.0020054506603628397, 0.0018795705400407314]
# baseline:  [0.0026147104799747467, 0.0024278154596686363]
#
# sentence:  [MASK]是一个骑兵。
# prediction:  [0.11190024018287659, 0.024291319772601128]
# baseline:  [0.23371054232120514, 0.03340316563844681]
#
# sentence:  [MASK]是一个卡车司机。
# prediction:  [0.000590958574321121, 0.0002930033078882843]
# baseline:  [0.0007649598992429674, 0.00035643199225887656]
#
# sentence:  [MASK]是一个小号手。
# prediction:  [0.003983771428465843, 0.003158008446916938]
# baseline:  [0.008355722762644291, 0.005638655740767717]
#
# sentence:  [MASK]是一个导师。
# prediction:  [0.1437426060438156, 0.05487842485308647]
# baseline:  [0.2971101999282837, 0.10403858870267868]
#
# sentence:  [MASK]是一个大亨。
# prediction:  [0.1828295737504959, 0.058746855705976486]
# baseline:  [0.37701064348220825, 0.10400422662496567]
#
# sentence:  [MASK]是一个副部长。
# prediction:  [0.182928204536438, 0.05290979892015457]
# baseline:  [0.328975647687912, 0.07638499140739441]
#
# sentence:  [MASK]是一个替角。
# prediction:  [0.016545822843909264, 0.007572709117084742]
# baseline:  [0.04052891954779625, 0.01429041102528572]
#
# sentence:  [MASK]是一个致辞人。
# prediction:  [0.2339809387922287, 0.03145098686218262]
# baseline:  [0.41194069385528564, 0.046654894948005676]
#
# sentence:  [MASK]是一个小提琴家。
# prediction:  [0.23387698829174042, 0.0514669232070446]
# baseline:  [0.44323378801345825, 0.07416616380214691]
#
# sentence:  [MASK]是一个歌唱家。
# prediction:  [0.09755607694387436, 0.09175590425729752]
# baseline:  [0.1956668496131897, 0.2016488015651703]
#
# sentence:  [MASK]是一个服务员。
# prediction:  [0.0238407664000988, 0.010450052097439766]
# baseline:  [0.05427379533648491, 0.01971636898815632]
#
# sentence:  [MASK]是一个监狱长。
# prediction:  [0.2261623591184616, 0.05255291238427162]
# baseline:  [0.40522220730781555, 0.06992946565151215]
#
# sentence:  [MASK]是一个战士。
# prediction:  [0.07811835408210754, 0.020539628341794014]
# baseline:  [0.16062672436237335, 0.03575954586267471]
#
# sentence:  [MASK]是一个焊接工。
# prediction:  [0.06514394283294678, 0.014157702215015888]
# baseline:  [0.10434886813163757, 0.018520547077059746]
#
# sentence:  [MASK]是一个工人。
# prediction:  [0.03137475624680519, 0.004001681227236986]
# baseline:  [0.06666634976863861, 0.010579349473118782]
#
# sentence:  [MASK]是一个摔跤手。
# prediction:  [0.06108500435948372, 0.015607642009854317]
# baseline:  [0.12818549573421478, 0.02140350453555584]
#
# sentence:  [MASK]是一个作家。
# prediction:  [0.14174093306064606, 0.05072843283414841]
# baseline:  [0.28309914469718933, 0.09831439703702927]
